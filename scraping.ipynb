# %% [markdown]
# # Scraping CRediT statements of journal articles

# %% [markdown]
# This code iteratively scrapes CRediT statements of journal articles. The list of articles to scrape were identified by using the "Writing – original draft" search term in the Dimensions AI database.

# %% [markdown]
# ## Importing packages

# %%
import os
import json
import re
import pandas as pd
from datetime import datetime
from bs4 import BeautifulSoup
import doi
import requests
import cloudscraper
from time import sleep
from pypdf import PdfReader
from selenium import webdriver
from selenium.webdriver import ChromeOptions
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
import pdfminer
from pdfminer.high_level import extract_text
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams, LTTextBox, LTTextLine, LTTextContainer
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser
from pdfminer.high_level import extract_pages
from io import StringIO

# %% [markdown]
# ## Exploring the dataset

# %% [markdown]
# Loading DOIs to scrape

# %%
with open(os.path.abspath("data/credit_observatory_publication_data.json")) as json_data:
    dimensions_data = json.load(json_data)

# %% [markdown]
# Looking at one result to see the structure.

# %%
dimensions_data[1]
# Out:
# {'_stats': {'total_count': 200},
#  'publications': [{'acknowledgements': 'We thank Ben Lehner, Mirko Francesconi, Nobert Perrimon, Thomas Richardson, Robin Evans, Jerome Reboul, Peter Sarkies, Yanhui Hu, and staff at the Drosophila RNAi Screening Center; Todd Harris, Kimberly van Auken, and staff at WormBase, for discussion and advice; Justine Melo and Emily Troemel for the kind gift of strains; Clement Ghigo and Sophie Cypowyj for their contributions; Pierre Golstein and Yishi Jin for critical reading of the manuscript; and the bioinformatics platforms of the CIML and the Laboratoire d’Informatique Fondamentale de Marseille for providing computing resources, database, and web servers. We are grateful to system administrators Manuel Bertrand and Kai Poutrain for their support and input, and the anonymous reviewers for their very constructive criticisms. Some nematode strains were provided by the Caenorhabditis Genetics Center, which is funded by NIH Office of Research Infrastructure Programs (P40 OD010440), or by the National Bioresource Project coordinated by S. Mitani.',
#    'altmetric': 21.0,
#    'altmetric_id': 7101087,
#    'authors_count': 10,
#    'category_for': [{'id': '80002', 'name': '31 Biological Sciences'},
#     {'id': '80035', 'name': '3102 Bioinformatics and Computational Biology'},
#     {'id': '80038', 'name': '3105 Genetics'}],
#    'concepts': ['antimicrobial peptide gene expression',
#     'C. elegans',
#     'RNAi screen',
#     'gene expression',
#     'genome-wide RNAi screen',
#     'whole-genome RNAi screen',
#     'forward genetic screen',
#     'animal innate immunity',
#     'RNAi-based screen',
#     'peptide gene expression',
#     'immune defense',
#     'systems-level insights',
#     'innate immunity',
#     'innate immunity genes',
#     'genetic screen',
#     'gene regulation',
#     'D. coniospora',
#     'Drechmeria coniospora',
#     'immunity genes',
#     'reverse genetics',
#     'elegans',
#     'molecular basis',
#     'nematode epidermis',
#     'MAPK pathway',
#     'level insights',
#     'mitochondrial dysfunction',
#     'genes',
#     'antimicrobial peptides',
#     'valuable resource',
#     'host defense',
#     'regulation',
#     'screen',
#     'expression',
#     'useful model',
#     'complementary approaches',
#     'defense',
#     'different steps',
#     'RNAi',
#     'epidermis',
#     'genetics',
#     'signaling',
#     'immunity',
#     'pathway',
#     'better comprehension',
#     'peptides',
#     'evolution',
#     'insights',
#     'intestine',
#     'last decade',
#     'interaction',
#     'function',
#     'understanding',
#     'significant contribution',
#     'basis',
#     'results',
#     'ConclusionsOverall',
#     'infection',
#     'step',
#     'limitations',
#     'ResultsWe',
#     'resources',
#     'strategies',
#     'clustering method',
#     'decades',
#     'dysfunction',
#     'study',
#     'complete description',
#     'approach',
#     'description',
#     'contribution',
#     'model',
#     'full results',
#     'method',
#     'comprehension'],
#    'date': '2016-04-29',
#    'doi': '10.1186/s12915-016-0256-3',
#    'field_citation_ratio': 5.86,
#    'id': 'pub.1034970431',
#    'journal': {'id': 'jour.1032884', 'title': 'BMC Biology'},
#    'journal_title_raw': 'BMC Biology',
#    'linkout': 'https://bmcbiol.biomedcentral.com/track/pdf/10.1186/s12915-016-0256-3',
#    'open_access': ['oa_all', 'gold'],
#    'publisher': 'Springer Nature',
#    'research_org_countries': [{'id': 'FR', 'name': 'France'},
#     {'id': 'US', 'name': 'United States'}],
#    'research_orgs': [{'acronym': 'I2M',
#      'city_name': 'Marseille',
#      'country_name': 'France',
#      'id': 'grid.473594.8',
#      'latitude': 43.235558,
#      'linkout': ['http://www.i2m.univ-amu.fr/?lang=fr'],
#      'longitude': 5.43963,
#      'name': 'Institut de Mathématiques de Marseille',
#      'types': ['Facility']},
#     {'acronym': 'OUHSC',
#      'city_name': 'Oklahoma City',
#      'country_name': 'United States',
#      'id': 'grid.266902.9',
#      'latitude': 35.480278,
#      'linkout': ['http://www.ouhsc.edu/'],
#      'longitude': -97.49639,
#      'name': 'University of Oklahoma Health Sciences Center',
#      'state_name': 'Oklahoma',
#      'types': ['Healthcare']},
#     {'acronym': 'IGF',
#      'city_name': 'Montpellier',
#      'country_name': 'France',
#      'id': 'grid.461890.2',
#      'latitude': 43.634956,
#      'linkout': ['http://www.igf.cnrs.fr/index.php/en/'],
#      'longitude': 3.846662,
#      'name': 'Institut de Génomique Fonctionnelle',
#      'types': ['Facility']},
#     {'acronym': 'CNRS',
#      'city_name': 'Paris',
#      'country_name': 'France',
#      'id': 'grid.4444.0',
#      'latitude': 48.847664,
#      'linkout': ['http://www.cnrs.fr/index.php'],
#      'longitude': 2.264034,
#      'name': 'French National Centre for Scientific Research',
#      'types': ['Government']}],
#    'researchers': [{'first_name': 'Olivier',
#      'id': 'ur.0631103503.79',
#      'last_name': 'Zugasti',
#      'orcid_id': ['0000-0002-5616-734X'],
#      'research_orgs': ['grid.4444.0',
#       'grid.417850.f',
#       'grid.428531.9',
#       'grid.7429.8',
#       'grid.5337.2',
#       'grid.457381.c',
#       'grid.462081.9',
#       'grid.5842.b',
#       'grid.429192.5']},
#     {'first_name': 'Nishant',
#      'id': 'ur.0722762337.15',
#      'last_name': 'Thakur',
#      'orcid_id': ['0000-0003-3699-0037'],
#      'research_orgs': ['grid.417641.1', 'grid.419681.3', 'grid.417850.f']},
#     {'first_name': 'Jérôme',
#      'id': 'ur.01170675101.48',
#      'last_name': 'Belougne',
#      'research_orgs': ['grid.5399.6', 'grid.417850.f', 'grid.462081.9']},
#     {'first_name': 'Barbara',
#      'id': 'ur.01055717403.72',
#      'last_name': 'Squiban',
#      'research_orgs': ['grid.266902.9', 'grid.417850.f']},
#     {'first_name': 'Cyril Léopold',
#      'id': 'ur.0653024473.50',
#      'last_name': 'Kurz',
#      'orcid_id': ['0000-0001-7081-3208'],
#      'research_orgs': ['grid.7429.8',
#       'grid.457381.c',
#       'grid.417850.f',
#       'grid.428531.9',
#       'grid.266902.9',
#       'grid.4444.0',
#       'grid.5399.6',
#       'grid.462081.9',
#       'grid.168010.e']},
#     {'first_name': 'Julien',
#      'id': 'ur.01120073351.51',
#      'last_name': 'Soulé',
#      'research_orgs': ['grid.461890.2', 'grid.417850.f']},
#     {'first_name': 'Shizue',
#      'id': 'ur.01253421461.51',
#      'last_name': 'Omi',
#      'orcid_id': ['0000-0002-2711-2016'],
#      'research_orgs': ['grid.428531.9',
#       'grid.5399.6',
#       'grid.417850.f',
#       'grid.457381.c',
#       'grid.7429.8',
#       'grid.418443.e',
#       'grid.4444.0',
#       'grid.462364.1']},
#     {'first_name': 'Laurent',
#      'id': 'ur.01005533722.51',
#      'last_name': 'Tichit',
#      'research_orgs': ['grid.473594.8', 'grid.5399.6']},
#     {'first_name': 'Nathalie',
#      'id': 'ur.01214066773.74',
#      'last_name': 'Pujol',
#      'orcid_id': ['0000-0001-8889-3197'],
#      'research_orgs': ['grid.4989.c',
#       'grid.417850.f',
#       'grid.11486.3a',
#       'grid.462081.9',
#       'grid.457381.c',
#       'grid.4444.0',
#       'grid.7429.8',
#       'grid.428531.9',
#       'grid.5399.6']},
#     {'first_name': 'Jonathan J',
#      'id': 'ur.0767253073.96',
#      'last_name': 'Ewbank',
#      'orcid_id': ['0000-0002-1257-6862'],
#      'research_orgs': ['grid.7429.8',
#       'grid.42475.30',
#       'grid.417850.f',
#       'grid.4444.0',
#       'grid.4709.a',
#       'grid.457381.c',
#       'grid.250086.9',
#       'grid.14709.3b',
#       'grid.5399.6',
#       'grid.428531.9',
#       'grid.51462.34']}],
#    'times_cited': 49,
#    'title': 'A quantitative genome-wide RNAi screen in C. elegans for antifungal innate immunity genes',
#    'type': 'article',
#    'year': 2016},
#   {'acknowledgements': 'We thank members of the A.K.B. laboratory for helpful discussions and Eric Hendrickson for critical reading of the manuscript. We also thank B. Stillman, X. Zhao, J.F.X. Diffley, G. Brush, M. Hochstrasser, and D. Moazed for generously sharing their reagents. We wish to acknowledge the University of Minnesota Flow Cytometry Resource and the Minnesota Supercomputing Institute. This work was supported by NIH grant GM074917 (A.K.B.) and partly through a scholarship by the Leukemia Lymphoma Society LLS1023-09 (A.K.B.). The authors recognize the Center for Mass Spectrometry and Proteomics at the University of Minnesota.',
#    'altmetric': 22.0,
#    'altmetric_id': 7080311,
#    'authors_count': 9,
#    'category_for': [{'id': '80034',
#      'name': '3101 Biochemistry and Cell Biology'},
#     {'id': '80002', 'name': '31 Biological Sciences'}],
#    'concepts': ['mcm10-1 mutants',
#     'chromosome passenger complex',
#     'replication stress',
#     'spindle assembly checkpoint activation',
#     'replication stress tolerance',
#     'Minichromosome maintenance protein 10',
#     'quantitative mass spectrometry',
#     'SUMO proteome',
#     'stress tolerance',
#     'E3 SUMO',
#     'passenger complex',
#     'mitotic progression',
#     'checkpoint activation',
#     'proteasomal degradation',
#     'Slx5/8',
#     'methyl methanesulfonate',
#     'mutants',
#     'BIR1',
#     'Mcm10 deficiency',
#     'SUMO',
#     'protein 10',
#     'Mms21',
#     'Sli15',
#     'mass spectrometry',
#     'proteome',
#     'such candidates',
#     'activation',
#     'mitosis',
#     'subunits',
#     'stress',
#     'methanesulfonate',
#     'tolerance',
#     'complexes',
#     'counteracts',
#     'degradation',
#     'progression',
#     'survival',
#     'candidates',
#     'spectrometry',
#     'deficiency',
#     'loss',
#     'changes',
#     'low doses',
#     'passage',
#     'findings',
#     'conditions',
#     'treatment',
#     'model',
#     'doses',
#     'relief'],
#    'date': '2016-04-28',
#    'doi': '10.1016/j.celrep.2016.04.017',
#    'field_citation_ratio': 2.41,
#    'id': 'pub.1048609593',
#    'journal': {'id': 'jour.1046010', 'title': 'Cell Reports'},
#    'journal_title_raw': 'Cell Reports',
#    'linkout': 'http://www.cell.com/article/S2211124716304302/pdf',
#    'open_access': ['oa_all', 'gold'],
#    'publisher': 'Elsevier',
#    'research_org_countries': [{'id': 'US', 'name': 'United States'}],
#    'research_orgs': [{'city_name': 'Minneapolis',
#      'country_name': 'United States',
#      'id': 'grid.17635.36',
#      'latitude': 44.974194,
#      'linkout': ['http://twin-cities.umn.edu/'],
#      'longitude': -93.22776,
#      'name': 'University of Minnesota',
#      'state_name': 'Minnesota',
#      'types': ['Education']}],
#    'researchers': [{'first_name': 'Yee Mon',
#      'id': 'ur.01311375473.87',
#      'last_name': 'Thu',
#      'orcid_id': ['0000-0002-9608-7336'],
#      'research_orgs': ['grid.452900.a',
#       'grid.152326.1',
#       'grid.412807.8',
#       'grid.252039.f',
#       'grid.17635.36']},
#     {'first_name': 'Susan Kaye',
#      'id': 'ur.01166051040.53',
#      'last_name': 'Van Riper',
#      'research_orgs': ['grid.440713.5', 'grid.17635.36']},
#     {'first_name': 'Lee Ann',
#      'id': 'ur.0777645630.02',
#      'last_name': 'Higgins',
#      'research_orgs': ['grid.17635.36',
#       'grid.255364.3',
#       'grid.214007.0',
#       'grid.9909.9',
#       'grid.437349.e']},
#     {'first_name': 'Tianji',
#      'id': 'ur.01357327030.94',
#      'last_name': 'Zhang',
#      'research_orgs': ['grid.17635.36']},
#     {'first_name': 'Jordan Robert',
#      'id': 'ur.0765271422.81',
#      'last_name': 'Becker',
#      'orcid_id': ['0000-0002-6827-0002'],
#      'research_orgs': ['grid.270683.8',
#       'grid.421962.a',
#       'grid.17635.36',
#       'grid.4991.5']},
#     {'first_name': 'Todd William',
#      'id': 'ur.0707236476.66',
#      'last_name': 'Markowski',
#      'orcid_id': ['0000-0001-9157-2036'],
#      'research_orgs': ['grid.17635.36', 'grid.437349.e']},
#     {'first_name': 'Hai Dang',
#      'id': 'ur.01136525371.97',
#      'last_name': 'Nguyen',
#      'orcid_id': ['0000-0002-4200-8778'],
#      'research_orgs': ['grid.17635.36',
#       'grid.516070.5',
#       'grid.38142.3c',
#       'grid.437349.e',
#       'grid.32224.35']},
#     {'first_name': 'Timothy Jon',
#      'id': 'ur.07775636537.00',
#      'last_name': 'Griffin',
#      'orcid_id': ['0000-0001-6801-2559'],
#      'research_orgs': ['grid.14003.36',
#       'grid.34477.33',
#       'grid.64212.33',
#       'grid.38142.3c',
#       'grid.17635.36',
#       'grid.421696.e',
#       'grid.437349.e',
#       'grid.482559.7']},
#     {'first_name': 'Anja-Katrin K',
#      'id': 'ur.01064543317.98',
#      'last_name': 'Bielinsky',
#      'orcid_id': ['0000-0003-1783-619X'],
#      'research_orgs': ['grid.413795.d',
#       'grid.17635.36',
#       'grid.27755.32',
#       'grid.437349.e',
#       'grid.516070.5',
#       'grid.411327.2',
#       'grid.12136.37',
#       'grid.40263.33']}],
#    'times_cited': 23,
#    'title': 'Slx5/Slx8 Promotes Replication Stress Tolerance by Facilitating Mitotic Progression',
#    'type': 'article',
#    'year': 2016},
#   {'acknowledgements': 'The authors thank the University of Nebraska Epigenomics Core Facility, UNMC Flow Cytometry Research Facility, and the UNMC Tissue Sciences Facilities. The authors also thank the DNA Services facility at the University of Illinois at Urbana-Champaign, Roy J. Carver Biotechnology Center/W.M. Keck Center, for performing WGBS. This work was supported by NIH/NCI grant 1R01CA188561-01A1 (R.O.), an Eppley Cancer Center pilot project grant (R.O.), an Institutional Development Award (IDeA) from the National Institute of General Medical Sciences of the NIH (5P30GM106397), and funding from the LB595 Nebraska Cancer and Smoking Disease Research Program (P.S.). S.L.H. and R.A.H. were supported by a UNMC fellowship. S.L.H. was supported by NIH T32 award CA009476.',
#    'altmetric': 5.0,
#    'altmetric_id': 7126582,
#    'authors_count': 15,
#    'category_for': [{'id': '80002', 'name': '31 Biological Sciences'},
#     {'id': '80038', 'name': '3105 Genetics'}],
#    'concepts': ['genome-wide methylation analysis',
#     'haplo-insufficient tumor suppressor',
#     'promoter hypomethylation',
#     'mammalian genomic DNA',
#     'mouse chronic lymphocytic leukemia',
#     'DNA methyltransferase 3A',
#     'gene expression analysis',
#     'CLL-like disease',
#     'expression analysis',
#     'methyltransferase 3A',
#     'genomic DNA',
#     'bi-allelic loss',
#     'tumor suppressor',
#     'molecular events',
#     'similar loci',
#     'mono-allelic loss',
#     'methylation analysis',
#     'human hematologic malignancies',
#     'putative oncogenic drivers',
#     'hypomethylation',
#     'oncogenic drivers',
#     'mice results',
#     'chronic lymphocytic leukemia',
#     'disease pathogenesis',
#     'genes',
#     'promoter',
#     'suppressor',
#     'loci',
#     'DNMT3A',
#     'DNA',
#     'lymphocytic leukemia',
#     'mice',
#     'expression',
#     'myeloproliferation',
#     'leukemia',
#     'loss',
#     'levels',
#     'pathogenesis',
#     'disease',
#     'analysis',
#     'formation',
#     'drivers',
#     'hematologic malignancies',
#     'decreased',
#     'events',
#     'importance',
#     'evidence',
#     'months of age',
#     'malignancy',
#     'data',
#     'results',
#     'lymphoma',
#     'months',
#     'age'],
#    'date': '2016-04-28',
#    'doi': '10.1016/j.celrep.2016.04.004',
#    'field_citation_ratio': 3.76,
#    'id': 'pub.1036495669',
#    'journal': {'id': 'jour.1046010', 'title': 'Cell Reports'},
#    'journal_title_raw': 'Cell Reports',
#    'linkout': 'http://www.cell.com/article/S221112471630403X/pdf',
#    'open_access': ['oa_all', 'gold'],
#    'publisher': 'Elsevier',
#    'research_org_countries': [{'id': 'US', 'name': 'United States'}],
#    'research_orgs': [{'city_name': 'Omaha',
#      'country_name': 'United States',
#      'id': 'grid.254748.8',
#      'latitude': 41.265236,
#      'linkout': ['http://www.creighton.edu/'],
#      'longitude': -95.94773,
#      'name': 'Creighton University',
#      'state_name': 'Nebraska',
#      'types': ['Education']},
#     {'acronym': 'UNMC',
#      'city_name': 'Omaha',
#      'country_name': 'United States',
#      'id': 'grid.266813.8',
#      'latitude': 41.255505,
#      'linkout': ['http://www.unmc.edu/'],
#      'longitude': -95.97682,
#      'name': 'University of Nebraska Medical Center',
#      'state_name': 'Nebraska',
#      'types': ['Healthcare']},
#     {'city_name': 'Omaha',
#      'country_name': 'United States',
#      'id': 'grid.516098.3',
#      'latitude': 41.254227,
#      'linkout': ['https://www.unmc.edu/cancercenter/'],
#      'longitude': -95.97797,
#      'name': 'Fred and Pamela Buffett Cancer Center',
#      'state_name': 'Nebraska',
#      'types': ['Healthcare']},
#     {'city_name': 'Rochester',
#      'country_name': 'United States',
#      'id': 'grid.66875.3a',
#      'latitude': 44.02407,
#      'linkout': ['http://www.mayoclinic.org/patient-visitor-guide/minnesota'],
#      'longitude': -92.46631,
#      'name': 'Mayo Clinic',
#      'state_name': 'Minnesota',
#      'types': ['Healthcare']}],
#    'researchers': [{'first_name': 'Staci L',
#      'id': 'ur.01201461601.60',
#      'last_name': 'Haney',
#      'research_orgs': ['grid.516098.3', 'grid.266813.8']},
#     {'first_name': 'Garland Michael',
#      'id': 'ur.01314303377.64',
#      'last_name': 'Upchurch',
#      'research_orgs': ['grid.265219.b',
#       'grid.274264.1',
#       'grid.266813.8',
#       'grid.4367.6']},
#     {'first_name': 'Jana',
#      'id': 'ur.01273736157.26',
#      'last_name': 'Opavska',
#      'research_orgs': ['grid.266813.8', 'grid.15276.37', 'grid.261331.4']},
#     {'first_name': 'David L',
#      'id': 'ur.01342051357.27',
#      'last_name': 'Klinkebiel',
#      'research_orgs': ['grid.266813.8', 'grid.516098.3']},
#     {'first_name': 'Ryan A',
#      'id': 'ur.01157507557.08',
#      'last_name': 'Hlady',
#      'research_orgs': ['grid.66875.3a', 'grid.266813.8']},
#     {'first_name': 'Samuel J',
#      'id': 'ur.016261374007.06',
#      'last_name': 'Pirruccello',
#      'research_orgs': ['grid.266813.8',
#       'grid.508115.8',
#       'grid.491585.4',
#       'grid.170693.a',
#       'grid.429696.6',
#       'grid.48336.3a',
#       'grid.17635.36',
#       'grid.468198.a']},
#     {'first_name': 'Vipul',
#      'id': 'ur.01071336305.29',
#      'last_name': 'Shukla',
#      'research_orgs': ['grid.16753.36', 'grid.185006.a', 'grid.266813.8']},
#     {'first_name': 'Runqing',
#      'id': 'ur.0707066571.29',
#      'last_name': 'Lu',
#      'research_orgs': ['grid.21107.35',
#       'grid.429696.6',
#       'grid.170205.1',
#       'grid.266813.8',
#       'grid.411024.2']},
#     {'first_name': 'Stefan',
#      'id': 'ur.01357677270.54',
#      'last_name': 'Costinean',
#      'research_orgs': ['grid.266813.8',
#       'grid.261331.4',
#       'grid.412332.5',
#       'grid.428458.7',
#       'grid.413944.f',
#       'grid.214007.0',
#       'grid.415231.0']},
#     {'first_name': 'Angie',
#      'id': 'ur.011035740337.37',
#      'last_name': 'Rizzino',
#      'research_orgs': ['grid.266813.8',
#       'grid.516098.3',
#       'grid.429696.6',
#       'grid.266815.e']},
#     {'first_name': 'Adam R',
#      'id': 'ur.01356745623.05',
#      'last_name': 'Karpf',
#      'orcid_id': ['0000-0002-0866-0666'],
#      'research_orgs': ['grid.429696.6',
#       'grid.266813.8',
#       'grid.240614.5',
#       'grid.170205.1',
#       'grid.223827.e',
#       'grid.251993.5',
#       'grid.273335.3',
#       'grid.479969.c',
#       'grid.516098.3',
#       'grid.89336.37',
#       'grid.258799.8',
#       'grid.10698.36']},
#     {'first_name': 'Shantaram S',
#      'id': 'ur.07355130657.98',
#      'last_name': 'Joshi',
#      'orcid_id': ['0000-0003-4748-5001'],
#      'research_orgs': ['grid.266815.e',
#       'grid.48336.3a',
#       'grid.411984.1',
#       'grid.417971.d',
#       'grid.257410.5',
#       'grid.266813.8']},
#     {'first_name': 'Patrick C',
#      'id': 'ur.01134063570.22',
#      'last_name': 'Swanson',
#      'research_orgs': ['grid.254748.8', 'grid.411930.e', 'grid.215654.1']},
#     {'first_name': 'Rene',
#      'id': 'ur.01141617415.14',
#      'last_name': 'Opavsky',
#      'orcid_id': ['0000-0002-5671-0920'],
#      'research_orgs': ['grid.516098.3',
#       'grid.413944.f',
#       'grid.266102.1',
#       'grid.426602.4',
#       'grid.15276.37',
#       'grid.94365.3d',
#       'grid.430508.a',
#       'grid.429696.6',
#       'grid.265008.9',
#       'grid.168010.e',
#       'grid.48336.3a',
#       'grid.266813.8',
#       'grid.261331.4']}],
#    'times_cited': 30,
#    'title': 'Promoter Hypomethylation and Expression Is Conserved in Mouse Chronic Lymphocytic Leukemia Induced by Decreased or Inactivated Dnmt3a',
#    'type': 'article',
#    'year': 2016},
#   {'acknowledgements': 'We thank Grace Gao, Marcin Iwanicki, Lisa Gallegos, Cheuk Leung, Taru Muranen, Angie Martinez Gakidis, John Blenis, Jessica Spinelli, Marcia Haigis, and Brandon Nicolay for reagents and/or helpful discussions. Images were acquired at The Nikon Imaging Center at Harvard Medical School. PAM50 subtype calls for the TCGA data were generously provided by Charles Perou. This research was supported by Roche Pharmaceuticals (J.S.B.) and a fellowship from the American Cancer Society (J.L.C.).',
#    'altmetric': 4.0,
#    'altmetric_id': 7059745,
#    'authors_count': 9,
#    'category_for': [{'id': '80048',
#      'name': '3205 Medical Biochemistry and Metabolomics'},
#     {'id': '80034', 'name': '3101 Biochemistry and Cell Biology'},
#     {'id': '80003', 'name': '32 Biomedical and Clinical Sciences'},
#     {'id': '80002', 'name': '31 Biological Sciences'}],
#    'concepts': ['NEAA synthesis',
#     'high transaminases',
#     'menstrual cycle',
#     'mammary epithelial cells',
#     'quiescent cells',
#     'epithelial cell transition',
#     'tissue culture model',
#     'glutamine consumption',
#     'human tumors',
#     'glutamate metabolism',
#     'more glutamate',
#     'cancer cells',
#     'epithelial cells',
#     'transaminase',
#     'cell proliferation',
#     'period of proliferation',
#     'significant differences',
#     'tricarboxylic acid (TCA) cycle anaplerosis',
#     'glutamate utilization',
#     'culture model',
#     'glutamate dehydrogenase',
#     'cells',
#     'acid synthesis',
#     'proliferation',
#     'metabolism',
#     'oncogenic transformation',
#     'cell transition',
#     'pregnancy',
#     'expression',
#     'tumors',
#     'glutamate',
#     'quantitative metabolomics',
#     'proliferating',
#     'quiescence',
#     'anaplerosis',
#     'metabolomics',
#     'findings',
#     'period',
#     'dehydrogenase',
#     'differences',
#     'amino acid synthesis',
#     'consumption',
#     'proteomics',
#     'development',
#     'relationship',
#     'utilization',
#     'synthesis',
#     'results',
#     'biosynthesis',
#     'nitrogen metabolism',
#     'cycle',
#     'model',
#     'generation',
#     'transformation',
#     'transition',
#     'coupling',
#     'redundant relationships',
#     'carbon'],
#    'date': '2016-04-28',
#    'doi': '10.1016/j.cmet.2016.03.016',
#    'field_citation_ratio': 22.88,
#    'id': 'pub.1023155938',
#    'journal': {'id': 'jour.1034535', 'title': 'Cell Metabolism'},
#    'journal_title_raw': 'Cell Metabolism',
#    'linkout': 'http://www.cell.com/article/S155041311630119X/pdf',
#    'open_access': ['oa_all', 'bronze'],
#    'publisher': 'Elsevier',
#    'research_org_countries': [{'id': 'JP', 'name': 'Japan'},
#     {'id': 'US', 'name': 'United States'}],
#    'research_orgs': [{'city_name': 'Cambridge',
#      'country_name': 'United States',
#      'id': 'grid.38142.3c',
#      'latitude': 42.377052,
#      'linkout': ['http://www.harvard.edu/'],
#      'longitude': -71.11665,
#      'name': 'Harvard University',
#      'state_name': 'Massachusetts',
#      'types': ['Education']}],
#    'researchers': [{'first_name': 'Jonathan L',
#      'id': 'ur.01242646337.00',
#      'last_name': 'Coloff',
#      'research_orgs': ['grid.24827.3b',
#       'grid.168645.8',
#       'grid.1052.6',
#       'grid.189509.c',
#       'grid.34421.30',
#       'grid.26009.3d',
#       'grid.89336.37',
#       'grid.38142.3c',
#       'grid.168010.e',
#       'grid.185648.6',
#       'grid.5386.8',
#       'grid.78028.35']},
#     {'first_name': 'John Patrick',
#      'id': 'ur.0727524504.35',
#      'last_name': 'Murphy',
#      'research_orgs': ['grid.139596.1',
#       'grid.418708.2',
#       'grid.55602.34',
#       'grid.38142.3c']},
#     {'first_name': 'Craig Ronald',
#      'id': 'ur.0675234173.90',
#      'last_name': 'Braun',
#      'research_orgs': ['grid.38142.3c',
#       'grid.65499.37',
#       'grid.2515.3',
#       'grid.418158.1']},
#     {'first_name': 'Isaac Spencer',
#      'id': 'ur.0662405411.48',
#      'last_name': 'Harris',
#      'orcid_id': ['0000-0002-6855-2763'],
#      'research_orgs': ['grid.412750.5',
#       'grid.1052.6',
#       'grid.415224.4',
#       'grid.16416.34',
#       'grid.38142.3c',
#       'grid.415502.7',
#       'grid.231844.8',
#       'grid.17063.33']},
#     {'first_name': 'Laura M',
#      'id': 'ur.0737324341.33',
#      'last_name': 'Shelton',
#      'research_orgs': ['grid.421397.a', 'grid.208226.c']},
#     {'first_name': 'Kenjiro',
#      'id': 'ur.01067137342.46',
#      'last_name': 'Kami',
#      'research_orgs': ['grid.26091.3c']},
#     {'first_name': 'Stephen P',
#      'id': 'ur.012070607257.17',
#      'last_name': 'Gygi',
#      'research_orgs': ['grid.59062.38',
#       'grid.64212.33',
#       'grid.223827.e',
#       'grid.239395.7',
#       'grid.134907.8',
#       'grid.10698.36',
#       'grid.516075.0',
#       'grid.65499.37',
#       'grid.420530.0',
#       'grid.12847.38',
#       'grid.38142.3c',
#       'grid.189504.1',
#       'grid.12136.37',
#       'grid.2515.3',
#       'grid.62560.37',
#       'grid.32224.35',
#       'grid.413454.3',
#       'grid.34477.33',
#       'grid.14709.3b',
#       'grid.5386.8']},
#     {'first_name': 'Laura M',
#      'id': 'ur.01345043275.23',
#      'last_name': 'Selfors',
#      'orcid_id': ['0000-0002-1317-7353'],
#      'research_orgs': ['grid.47100.32',
#       'grid.1052.6',
#       'grid.38142.3c',
#       'grid.208226.c']},
#     {'first_name': 'Joan Siefert',
#      'id': 'ur.01053503703.00',
#      'last_name': 'Brugge',
#      'research_orgs': ['grid.419849.9',
#       'grid.417886.4',
#       'grid.67105.35',
#       'grid.65499.37',
#       'grid.14003.36',
#       'grid.214007.0',
#       'grid.62560.37',
#       'grid.280051.e',
#       'grid.189747.4',
#       'grid.516087.d',
#       'grid.25879.31',
#       'grid.412695.d',
#       'grid.451362.7',
#       'grid.413575.1',
#       'grid.1052.6',
#       'grid.417993.1',
#       'grid.413085.b',
#       'grid.32224.35',
#       'grid.239395.7',
#       'grid.414016.6',
#       'grid.24827.3b',
#       'grid.66859.34',
#       'grid.36425.36',
#       'grid.59734.3c',
#       'grid.38142.3c']}],
#    'times_cited': 204,
#    'title': 'Differential Glutamate Metabolism in Proliferating and Quiescent Mammary Epithelial Cells',
#    'type': 'article',
#    'year': 2016},
#   {'acknowledgements': 'This work was supported by NIH grant R01AI078962 to K.S. and supplement R01AI014102-37S1 to K.S. and I.C., and AHA fellowship 14POST18970046 to I.C. S.S. and N.S.M. received support from Fundacão de Amparo à Pesquisa do Estado de São Paulo (FAPESP, 2011/51973-3 to S.S. and 2012/09403-8 and 2013/20074-9 to N.S.M.) and by Conselho Nacional de Desenvolvimento Científico e Tecnológico (CNPq, 477143/2011-3 to S.S.). We thank GSK for the compound library and Anna Sokolov for administrative support.',
#    'altmetric': 7.0,
#    'altmetric_id': 7561327,
#    'authors_count': 5,
#    'category_for': [{'id': '80002', 'name': '31 Biological Sciences'},
#     {'id': '80068', 'name': '3404 Medicinal and Biomolecular Chemistry'},
#     {'id': '80005', 'name': '34 Chemical Sciences'}],
#    'concepts': ['inositol polyphosphate multikinase',
#     'drug targets',
#     'phosphate pathway genes',
#     'Chemogenetic characterization',
#     'viable drug target',
#     'chemical screen',
#     'kinetoplastid parasites',
#     'pathway steps',
#     'pathway genes',
#     'druggable enzymes',
#     'kinetoplastids',
#     'metabolic pathways',
#     'Trypanosoma cruzi',
#     'IP pathway',
#     'parasite growth',
#     'Chagas disease',
#     'enzyme',
#     'pathway',
#     'inhibitors',
#     'human African trypanosomiasis',
#     'African trypanosomiasis',
#     'multikinase',
#     'new drugs',
#     'target',
#     'chemogenetic approach',
#     'brucei',
#     'genes',
#     'phosphorylation',
#     'Trypanosoma',
#     'cruzi',
#     'parasites',
#     'limited knowledge',
#     'screen',
#     'inhibition',
#     'growth',
#     'trypanosomiasis',
#     'leishmaniases',
#     'development',
#     'characterization',
#     'disease',
#     'infection',
#     'step',
#     'drugs',
#     'knowledge',
#     'treatment',
#     'current treatment',
#     'approach',
#     'series',
#     'IP'],
#    'date': '2016-04-28',
#    'doi': '10.1016/j.chembiol.2016.03.015',
#    'field_citation_ratio': 2.03,
#    'id': 'pub.1020380404',
#    'journal': {'id': 'jour.1053068', 'title': 'Cell Chemical Biology'},
#    'journal_title_raw': 'Cell Chemical Biology',
#    'linkout': 'http://www.cell.com/article/S2451945616300939/pdf',
#    'open_access': ['oa_all', 'bronze'],
#    'publisher': 'Elsevier',
#    'research_org_countries': [{'id': 'US', 'name': 'United States'},
#     {'id': 'BR', 'name': 'Brazil'}],
#    'research_orgs': [{'acronym': 'UNIFESP',
#      'city_name': 'São Paulo',
#      'country_name': 'Brazil',
#      'id': 'grid.411249.b',
#      'latitude': -23.59162,
#      'linkout': ['http://www.unifesp.br/'],
#      'longitude': -46.649025,
#      'name': 'Federal University of São Paulo',
#      'types': ['Education']},
#     {'acronym': 'SBRI',
#      'city_name': 'Seattle',
#      'country_name': 'United States',
#      'id': 'grid.53964.3d',
#      'latitude': 47.621292,
#      'linkout': ['http://www.cidresearch.org/'],
#      'longitude': -122.33881,
#      'name': 'Center for Infectious Disease Research',
#      'state_name': 'Washington',
#      'types': ['Nonprofit']},
#     {'acronym': 'UW',
#      'city_name': 'Seattle',
#      'country_name': 'United States',
#      'id': 'grid.34477.33',
#      'latitude': 47.655537,
#      'linkout': ['http://www.washington.edu/'],
#      'longitude': -122.30353,
#      'name': 'University of Washington',
#      'state_name': 'Washington',
#      'types': ['Education']}],
#    'researchers': [{'first_name': 'Igor Dos Santos',
#      'id': 'ur.01256577744.06',
#      'last_name': 'Cestari',
#      'research_orgs': ['grid.240741.4',
#       'grid.53964.3d',
#       'grid.14709.3b',
#       'grid.418068.3',
#       'grid.23231.31']},
#     {'first_name': 'Paige',
#      'id': 'ur.014734677773.34',
#      'last_name': 'Haas',
#      'orcid_id': ['0000-0001-8303-457X'],
#      'research_orgs': ['grid.266102.1', 'grid.249878.8', 'grid.53964.3d']},
#     {'first_name': 'Nilmar Silvio',
#      'id': 'ur.01046127512.69',
#      'last_name': 'Moretti',
#      'orcid_id': ['0000-0003-0455-2497'],
#      'research_orgs': ['grid.240741.4', 'grid.411249.b', 'grid.53964.3d']},
#     {'first_name': 'Sergio',
#      'id': 'ur.01333154566.35',
#      'last_name': 'Schenkman',
#      'orcid_id': ['0000-0001-9353-8480'],
#      'research_orgs': ['grid.15276.37',
#       'grid.240324.3',
#       'grid.4709.a',
#       'grid.10383.39',
#       'grid.417758.8',
#       'grid.411249.b',
#       'grid.11899.38',
#       'grid.7372.1',
#       'grid.213876.9',
#       'grid.137628.9',
#       'grid.8430.f']},
#     {'first_name': 'Ken',
#      'id': 'ur.013525734402.44',
#      'last_name': 'Stuart',
#      'research_orgs': ['grid.240741.4',
#       'grid.53964.3d',
#       'grid.34477.33',
#       'grid.270240.3']}],
#    'times_cited': 21,
#    'title': 'Chemogenetic Characterization of Inositol Phosphate Metabolic Pathway Reveals Druggable Enzymes for Targeting Kinetoplastid Parasites',
#    'type': 'article',
#    'year': 2016},
#   {'acknowledgements': 'This work was supported by a grant from the DFG (BR 1492/7-1) to J.C.B., and received funding by the DFG within the framework of the TRR134 and within the CMMC and the Excellence Initiative by German Federal and State Governments (CECAD). This work was funded (in part) by the Helmholtz Alliance ICEMED (Imaging and Curing Environmental Metabolic Diseases) through the Initiative and Networking Fund of the Helmholtz Association. Moreover, the research leading to these results has received funding from the European Union Seventh Framework Program (FP7/2007-2013) under grant agreement 266408. S.M.S. was funded by the Humboldt-Bayer program of the Alexander Von Humboldt foundation and received a grant from the Excellence Cluster on Cellular Stress Responses in Aging Associated Diseases (CECAD). A.K. was supported by a DFG fellowship KL2399-3/1. S.T. was funded by a scholarship-program (Gerok-Rotationsstelle, No. 3/2014) of the Medical Faculty of the University of Cologne. G.K. was funded by the National Institute on Aging (NIA) grant 1R01DK104727-01A1. [18F]FDG was provided by B. Neumaier and the radiochemistry department of the Max Planck Institute for Metabolism Research.',
#    'altmetric': 109.0,
#    'altmetric_id': 7059087,
#    'authors_count': 17,
#    'category_for': [{'id': '80034',
#      'name': '3101 Biochemistry and Cell Biology'},
#     {'id': '80002', 'name': '31 Biological Sciences'}],
#    'concepts': ['brain glucose uptake',
#     'vascular endothelial growth factor',
#     'glucose uptake',
#     'HFD feeding',
#     'lean mice',
#     'disease background',
#     'GLUT1 expression',
#     'VEGF serum concentrations',
#     'cerebral glucose metabolism',
#     'endothelial growth factor',
#     'vascular endothelial cells',
#     'serum concentrations',
#     'systemic metabolism',
#     'glucose metabolism',
#     'macrophage activation',
#     'cognitive decline',
#     'homeostatic role',
#     'cognitive impairment',
#     'compensatory increase',
#     'increased expression',
#     'VEGF production',
#     'cognitive function',
#     'endothelial cells',
#     'growth factor',
#     'memory formation',
#     'specific deletion',
#     'obesity',
#     'mice',
#     'inducible reduction',
#     'glucose transporter',
#     'expression',
#     'metabolism',
#     'uptake',
#     'feeding',
#     'neuroinflammation',
#     'obese',
#     'HFD',
#     'BBB',
#     'macrophages',
#     'neurodegeneration',
#     'progression',
#     'impairment',
#     'activation',
#     'reduction',
#     'cells',
#     'transporters',
#     'factors',
#     'deletion',
#     'decline',
#     'reprogramming',
#     'background',
#     'role',
#     'increase',
#     'concentration',
#     'rapid reprogramming',
#     'function',
#     'production',
#     'turn',
#     'formation',
#     'experiments'],
#    'date': '2016-04-28',
#    'doi': '10.1016/j.cell.2016.03.033',
#    'field_citation_ratio': 13.92,
#    'id': 'pub.1010797599',
#    'journal': {'id': 'jour.1019114', 'title': 'Cell'},
#    'journal_title_raw': 'Cell',
#    'linkout': 'http://www.cell.com/article/S0092867416303312/pdf',
#    'open_access': ['oa_all', 'bronze'],
#    'publisher': 'Elsevier',
#    'research_org_countries': [{'id': 'DE', 'name': 'Germany'},
#     {'id': 'US', 'name': 'United States'}],
#    'research_orgs': [{'acronym': 'DIfE',
#      'city_name': 'Potsdam',
#      'country_name': 'Germany',
#      'id': 'grid.418213.d',
#      'latitude': 52.348442,
#      'linkout': ['http://www.dife.de/?lang=en'],
#      'longitude': 13.105172,
#      'name': 'German Institute of Human Nutrition',
#      'types': ['Facility']},
#     {'city_name': 'Lübeck',
#      'country_name': 'Germany',
#      'id': 'grid.4562.5',
#      'latitude': 53.836945,
#      'linkout': ['http://www.uni-luebeck.de/'],
#      'longitude': 10.705833,
#      'name': 'University of Lübeck',
#      'state_name': 'Schleswig-Holstein',
#      'types': ['Education']},
#     {'city_name': 'Cologne',
#      'country_name': 'Germany',
#      'id': 'grid.6190.e',
#      'latitude': 50.928055,
#      'linkout': ['http://www.portal.uni-koeln.de/'],
#      'longitude': 6.928611,
#      'name': 'University of Cologne',
#      'types': ['Education']},
#     {'city_name': 'Wurzburg',
#      'country_name': 'Germany',
#      'id': 'grid.8379.5',
#      'latitude': 49.788055,
#      'linkout': ['http://www.uni-wuerzburg.de/en/ueber/university/'],
#      'longitude': 9.935278,
#      'name': 'University of Würzburg',
#      'state_name': 'Bayern',
#      'types': ['Education']},
#     {'acronym': 'CU',
#      'city_name': 'New York',
#      'country_name': 'United States',
#      'id': 'grid.21729.3f',
#      'latitude': 40.8076,
#      'linkout': ['http://www.columbia.edu/'],
#      'longitude': -73.96239,
#      'name': 'Columbia University',
#      'state_name': 'New York',
#      'types': ['Education']},
#     {'city_name': 'La Jolla',
#      'country_name': 'United States',
#      'id': 'grid.516081.b',
#      'latitude': 32.878647,
#      'linkout': ['https://moorescancercenter.ucsd.edu/'],
#      'longitude': -117.22306,
#      'name': 'Moores Comprehensive Cancer Center',
#      'state_name': 'California',
#      'types': ['Healthcare']},
#     {'acronym': 'CECAD',
#      'city_name': 'Cologne',
#      'country_name': 'Germany',
#      'id': 'grid.452408.f',
#      'latitude': 50.92552,
#      'linkout': ['https://www.cecad.uni-koeln.de/'],
#      'longitude': 6.920315,
#      'name': 'Cluster of Excellence "CECAD - Excellent in Aging Research"',
#      'types': ['Facility']},
#     {'city_name': 'Cologne',
#      'country_name': 'Germany',
#      'id': 'grid.418034.a',
#      'latitude': 50.92608,
#      'linkout': ['http://www.sf.mpg.de/en'],
#      'longitude': 6.916579,
#      'name': 'Max Planck Institute for Metabolism Research',
#      'types': ['Facility']},
#     {'city_name': 'Cologne',
#      'country_name': 'Germany',
#      'id': 'grid.411097.a',
#      'latitude': 50.923904,
#      'linkout': ['http://www.uk-koeln.de/'],
#      'longitude': 6.916884,
#      'name': 'University Hospital Cologne',
#      'types': ['Healthcare']}],
#    'researchers': [{'first_name': 'Alexander',
#      'id': 'ur.01302161031.85',
#      'last_name': 'Jais',
#      'orcid_id': ['0000-0002-9897-4983'],
#      'research_orgs': ['grid.6583.8',
#       'grid.22937.3d',
#       'grid.411097.a',
#       'grid.411339.d',
#       'grid.418034.a',
#       'grid.6190.e',
#       'grid.452408.f']},
#     {'first_name': 'Maite',
#      'id': 'ur.01366117300.66',
#      'last_name': 'Solas',
#      'orcid_id': ['0000-0001-7670-3237'],
#      'research_orgs': ['grid.418034.a',
#       'grid.5924.a',
#       'grid.508840.1',
#       'grid.452408.f',
#       'grid.411097.a',
#       'grid.6190.e']},
#     {'first_name': 'Heiko',
#      'id': 'ur.01147161332.94',
#      'last_name': 'Backes',
#      'research_orgs': ['grid.4372.2',
#       'grid.5949.1',
#       'grid.411097.a',
#       'grid.419818.d',
#       'grid.418034.a',
#       'grid.6190.e',
#       'grid.8385.6',
#       'grid.452408.f']},
#     {'first_name': 'Bhagirath',
#      'id': 'ur.0607620671.05',
#      'last_name': 'Chaurasia',
#      'orcid_id': ['0000-0002-7998-9290'],
#      'research_orgs': ['grid.223827.e',
#       'grid.428397.3',
#       'grid.418034.a',
#       'grid.1051.5',
#       'grid.214572.7',
#       'grid.6190.e',
#       'grid.452408.f']},
#     {'first_name': 'André',
#      'id': 'ur.01341702772.71',
#      'last_name': 'Kleinridders',
#      'orcid_id': ['0000-0002-4248-6366'],
#      'research_orgs': ['grid.38142.3c',
#       'grid.62560.37',
#       'grid.16694.3c',
#       'grid.418034.a',
#       'grid.452622.5',
#       'grid.419502.b',
#       'grid.452408.f',
#       'grid.411097.a',
#       'grid.418213.d',
#       'grid.6190.e',
#       'grid.11348.3f']},
#     {'first_name': 'Sebastian',
#      'id': 'ur.0754145460.42',
#      'last_name': 'Theurich',
#      'orcid_id': ['0000-0001-5706-8258'],
#      'research_orgs': ['grid.7468.d',
#       'grid.461820.9',
#       'grid.7497.d',
#       'grid.5252.0',
#       'grid.411097.a',
#       'grid.411095.8',
#       'grid.418034.a',
#       'grid.251993.5',
#       'grid.6363.0',
#       'grid.6190.e',
#       'grid.452408.f',
#       'grid.9018.0',
#       'grid.413131.5']},
#     {'first_name': 'Jan',
#      'id': 'ur.0655734071.41',
#      'last_name': 'Mauer',
#      'orcid_id': ['0000-0002-0189-5876'],
#      'research_orgs': ['grid.7892.4',
#       'grid.418034.a',
#       'grid.6190.e',
#       'grid.411097.a',
#       'grid.419481.1',
#       'grid.419502.b',
#       'grid.5386.8',
#       'grid.452408.f',
#       'grid.512452.5']},
#     {'first_name': 'Sophie Marie',
#      'id': 'ur.01257401106.12',
#      'last_name': 'Steculorum',
#      'orcid_id': ['0000-0002-5665-2732'],
#      'research_orgs': ['grid.411097.a',
#       'grid.503422.2',
#       'grid.418034.a',
#       'grid.452408.f',
#       'grid.239546.f',
#       'grid.7429.8',
#       'grid.6190.e',
#       'grid.42505.36',
#       'grid.452622.5']},
#     {'first_name': 'Brigitte',
#      'id': 'ur.0635127451.22',
#      'last_name': 'Hampel',
#      'research_orgs': ['grid.7892.4',
#       'grid.452408.f',
#       'grid.418034.a',
#       'grid.459194.4',
#       'grid.6190.e',
#       'grid.411097.a']},
#     {'first_name': 'Julia',
#      'id': 'ur.0772162471.38',
#      'last_name': 'Goldau',
#      'research_orgs': ['grid.411097.a', 'grid.418034.a', 'grid.6190.e']},
#     {'first_name': 'Jens',
#      'id': 'ur.0751114520.33',
#      'last_name': 'Alber',
#      'research_orgs': ['grid.7892.4',
#       'grid.38142.3c',
#       'grid.452408.f',
#       'grid.418034.a',
#       'grid.459194.4',
#       'grid.6190.e',
#       'grid.411097.a']},
#     {'first_name': 'Carola Yvette',
#      'id': 'ur.01221763465.86',
#      'last_name': 'Förster',
#      'orcid_id': ['0000-0002-3878-247X'],
#      'research_orgs': ['grid.4714.6',
#       'grid.5802.f',
#       'grid.5949.1',
#       'grid.411760.5',
#       'grid.10423.34',
#       'grid.8379.5',
#       'grid.10420.37',
#       'grid.5386.8',
#       'grid.83440.3b',
#       'grid.1374.1']},
#     {'first_name': 'Sabine Anne',
#      'id': 'ur.01003552050.34',
#      'last_name': 'Eming',
#      'research_orgs': ['grid.415829.3',
#       'grid.452408.f',
#       'grid.412966.e',
#       'grid.462046.2',
#       'grid.32224.35',
#       'grid.8273.e',
#       'grid.6190.e',
#       'grid.48336.3a',
#       'grid.10493.3f',
#       'grid.411097.a',
#       'grid.412041.2',
#       'grid.8155.9',
#       'grid.10420.37',
#       'grid.8379.5',
#       'grid.16149.3b',
#       'grid.8664.c',
#       'grid.411778.c',
#       'grid.10388.32',
#       'grid.214007.0',
#       'grid.7700.0',
#       'grid.11749.3a',
#       'grid.5570.7',
#       'grid.11348.3f',
#       'grid.38142.3c']},
#     {'first_name': 'Markus',
#      'id': 'ur.01266161341.90',
#      'last_name': 'Schwaninger',
#      'orcid_id': ['0000-0002-4510-9718'],
#      'research_orgs': ['grid.9668.1',
#       'grid.4562.5',
#       'grid.419491.0',
#       'grid.15090.3d',
#       'grid.8993.b',
#       'grid.5963.9',
#       'grid.457348.9',
#       'grid.415721.4',
#       'grid.413335.3',
#       'grid.5379.8',
#       'grid.9024.f',
#       'grid.5734.5',
#       'grid.6827.b',
#       'grid.134907.8',
#       'grid.7892.4',
#       'grid.452396.f',
#       'grid.5802.f',
#       'grid.419800.4',
#       'grid.413030.5',
#       'grid.266093.8',
#       'grid.270683.8',
#       'grid.7450.6',
#       'grid.10403.36',
#       'grid.410567.1',
#       'grid.6936.a',
#       'grid.11794.3a',
#       'grid.461718.d',
#       'grid.10253.35',
#       'grid.8756.c',
#       'grid.7700.0',
#       'grid.412468.d',
#       'grid.413734.6',
#       'grid.411327.2',
#       'grid.1649.a',
#       'grid.4514.4',
#       'grid.6363.0',
#       'grid.434949.7',
#       'grid.410463.4',
#       'grid.7563.7',
#       'grid.9764.c',
#       'grid.10025.36',
#       'grid.26091.3c',
#       'grid.5253.1',
#       'grid.21729.3f']},
#     {'first_name': 'Napoleone M A',
#      'id': 'ur.01203276767.04',
#      'last_name': 'Ferrara',
#      'research_orgs': ['grid.21107.35',
#       'grid.8158.4',
#       'grid.189504.1',
#       'grid.38142.3c',
#       'grid.83440.3b',
#       'grid.14003.36',
#       'grid.32224.35',
#       'grid.7872.a',
#       'grid.48336.3a',
#       'grid.266100.3',
#       'grid.5963.9',
#       'grid.516081.b',
#       'grid.28046.38',
#       'grid.280268.6',
#       'grid.266102.1',
#       'grid.418158.1',
#       'grid.416167.3',
#       'grid.415235.4',
#       'grid.419227.b',
#       'grid.150338.c',
#       'grid.59734.3c',
#       'grid.418424.f',
#       'grid.9668.1',
#       'grid.415720.5',
#       'grid.413086.8',
#       'grid.7841.a',
#       'grid.250674.2',
#       'grid.185648.6',
#       'grid.413480.a',
#       'grid.7737.4',
#       'grid.453260.6',
#       'grid.411249.b',
#       'grid.30389.31',
#       'grid.47100.32',
#       'grid.240845.f',
#       'grid.413077.6']},
#     {'first_name': 'Gerard',
#      'id': 'ur.01272063751.22',
#      'last_name': 'Karsenty',
#      'orcid_id': ['0000-0002-9253-7627'],
#      'research_orgs': ['grid.416975.8',
#       'grid.189509.c',
#       'grid.415833.8',
#       'grid.411266.6',
#       'grid.239585.0',
#       'grid.7497.d',
#       'grid.281219.1',
#       'grid.39382.33',
#       'grid.240145.6',
#       'grid.414438.e',
#       'grid.21729.3f',
#       'grid.266100.3',
#       'grid.411535.7',
#       'grid.214458.e',
#       'grid.265073.5',
#       'grid.14709.3b',
#       'grid.277151.7',
#       'grid.239395.7',
#       'grid.48336.3a',
#       'grid.414441.0',
#       'grid.413734.6',
#       'grid.414336.7',
#       'grid.411394.a',
#       'grid.32224.35',
#       'grid.413328.f',
#       'grid.457369.a',
#       'grid.411296.9',
#       'grid.412180.e',
#       'grid.267309.9',
#       'grid.411119.d',
#       'grid.411572.4',
#       'grid.414214.6',
#       'grid.420255.4',
#       'grid.414244.3',
#       'grid.412134.1',
#       'grid.1008.9',
#       'grid.410513.2',
#       'grid.10306.34',
#       'grid.280051.e',
#       'grid.508989.5',
#       'grid.258799.8',
#       'grid.414240.7',
#       'grid.5399.6',
#       'grid.412408.b',
#       'grid.411777.3',
#       'grid.7727.5',
#       'grid.34477.33',
#       'grid.47100.32',
#       'grid.9026.d',
#       'grid.267308.8',
#       'grid.94365.3d']},
#     {'first_name': 'Jens Claus',
#      'id': 'ur.0641565372.08',
#      'last_name': 'Brüning',
#      'research_orgs': ['grid.9001.8',
#       'grid.452408.f',
#       'grid.488604.6',
#       'grid.417993.1',
#       'grid.420089.7',
#       'grid.461798.5',
#       'grid.63368.38',
#       'grid.452622.5',
#       'grid.6190.e',
#       'grid.7892.4',
#       'grid.11135.37',
#       'grid.459194.4',
#       'grid.21107.35',
#       'grid.411097.a',
#       'grid.249880.f',
#       'grid.418034.a',
#       'grid.419502.b',
#       'grid.4991.5',
#       'grid.4372.2',
#       'grid.239395.7',
#       'grid.83440.3b',
#       'grid.38142.3c']}],
#    'times_cited': 133,
#    'title': 'Myeloid-Cell-Derived VEGF Maintains Brain Glucose Uptake and Limits Cognitive Impairment in Obesity',
#    'type': 'article',
#    'year': 2016},
#   {'acknowledgements': 'We thank P. Lorentz (Department of Biomedicine [DBM], University of Basel) for excellent support with microscopy; H. Antoniadis, P. Schmidt, and I. Galm (DBM) for technical support; as well as T. Barthlott, C. Berkemeier, and C. Mayer (DBM) for flow cytometry and R. Ivanek (DBM) for bioinformatics analysis. We highly appreciate the collaboration with S. Dubuis and N. Zamboni (Institute for Systems Biology, ETH Zürich) on metabolomic analysis. We are grateful to D. Gruber, A. Banfi, and O. Pertz (DBM) and M. Hall (Biocenter, University of Basel) for providing reagents. This work was supported by the Swiss Cancer League (5KLS-2846-08-2011) and a MD-PhD fellowship to R.B. by the Swiss National Science Foundation.',
#    'altmetric': 81.0,
#    'altmetric_id': 7075940,
#    'authors_count': 8,
#    'category_for': [{'id': '80002', 'name': '31 Biological Sciences'}],
#    'concepts': ['anti-angiogenic therapy',
#     'rapid tumor recurrence',
#     'metabolic symbiosis',
#     'anti-angiogenic efficacy',
#     'tumor recurrence',
#     'clinical results',
#     'breast cancer',
#     'transient benefit',
#     'mouse model',
#     'MCT4 expression',
#     'tumor growth',
#     'tumor angiogenesis',
#     'combinatorial treatment',
#     'therapy',
#     'glycolytic tumors',
#     'genetic ablation',
#     'tumor cells',
#     'initial regression',
#     'gene expression profiling',
#     'tumors',
#     'glycolysis inhibitor',
#     'adaptive resistance',
#     'metabolic reprogramming',
#     'lactate exchange',
#     'monocarboxylate transporters',
#     'anaerobic glycolysis',
#     'resistance development',
#     'differential expression',
#     'expression profiling',
#     'nintedanib',
#     'patients',
#     'recurrence',
#     'expression',
#     'cancer',
#     'angiogenesis',
#     'efficacy',
#     'MCT4',
#     'MCT1',
#     'treatment',
#     'inhibitors',
#     'ablation',
#     'approval',
#     'glycolysis',
#     'attractive avenue',
#     'cells',
#     'resistance',
#     'regression',
#     'transporters',
#     'absence',
#     'reprogramming',
#     'benefits',
#     'profiling',
#     'growth',
#     'development',
#     'avenues',
#     'results',
#     'model',
#     'exchange',
#     'symbiosis'],
#    'date': '2016-04-28',
#    'doi': '10.1016/j.celrep.2016.04.028',
#    'id': 'pub.1003324282',
#    'journal': {'id': 'jour.1046010', 'title': 'Cell Reports'},
#    'journal_title_raw': 'Cell Reports',
#    'linkout': 'http://www.cell.com/article/S2211124716304417/pdf',
#    'open_access': ['oa_all', 'gold'],
#    'publisher': 'Elsevier',
#    'research_org_countries': [{'id': 'CH', 'name': 'Switzerland'}],
#    'research_orgs': [{'city_name': 'Basel',
#      'country_name': 'Switzerland',
#      'id': 'grid.6612.3',
# ...
#    'altmetric': 178.0,
#    'altmetric_id': 4962069,
#    'authors_count': 8,
#    'category_for': [{'id': '80232', 'name': '5202 Biological Psychology'},
#     {'id': '80057', 'name': '3214 Pharmacology and Pharmaceutical Sciences'},
#     {'id': '80003', 'name': '32 Biomedical and Clinical Sciences'},
#     {'id': '80023', 'name': '52 Psychology'}],
#    'concepts': ['area CA2',
#     'mouse model',
#     'neuropsychiatric disorders',
#     'CA2 pyramidal neurons',
#     'parvalbumin-expressing interneurons',
#     'action potential firing',
#     'social memory deficits',
#     'genetic risk factors',
#     'social memory formation',
#     'pyramidal neurons',
#     'risk factors',
#     'postmortem studies',
#     'psychiatric illness',
#     'feedforward inhibition',
#     'specific changes',
#     'psychiatric disorders',
#     'mice display',
#     'memory deficits',
#     'deletion syndrome',
#     'potential mechanisms',
#     'memory formation',
#     'neural substrates',
#     'social dysfunction',
#     'disorders',
#     'hippocampus',
#     'schizophrenia',
#     'Ca2',
#     'patients',
#     'dysfunction',
#     'interneurons',
#     'syndrome',
#     'illness',
#     'mice',
#     'neurons',
#     'impairment',
#     'microdeletion',
#     'inhibition',
#     'deficits',
#     'alterations',
#     'changes',
#     'firing',
#     'factors',
#     'decrease',
#     'study',
#     'cognition',
#     'reduction',
#     'mechanism',
#     'social cognition',
#     'intrinsic properties',
#     'model',
#     'amount',
#     'region',
#     'formation',
#     'display',
#     'density',
#     'plastic',
#     'substrate',
#     'properties'],
#    'date': '2016-01-01',
#    'doi': '10.1016/j.neuron.2015.11.036',
#    'field_citation_ratio': 19.44,
#    'id': 'pub.1005444581',
#    'journal': {'id': 'jour.1098485', 'title': 'Neuron'},
#    'journal_title_raw': 'Neuron',
#    'linkout': 'http://www.cell.com/article/S0896627315010788/pdf',
#    'open_access': ['oa_all', 'bronze'],
#    'publisher': 'Elsevier',
#    'research_org_countries': [{'id': 'FR', 'name': 'France'},
#     {'id': 'US', 'name': 'United States'}],
#    'research_orgs': [{'city_name': 'Paris',
#      'country_name': 'France',
#      'id': 'grid.508487.6',
#      'latitude': 48.863808,
#      'linkout': ['https://u-paris.fr/en'],
#      'longitude': 2.329205,
#      'name': 'Université Paris-Cité',
#      'types': ['Education']},
#     {'acronym': 'CU',
#      'city_name': 'New York',
#      'country_name': 'United States',
#      'id': 'grid.21729.3f',
#      'latitude': 40.8076,
#      'linkout': ['http://www.columbia.edu/'],
#      'longitude': -73.96239,
#      'name': 'Columbia University',
#      'state_name': 'New York',
#      'types': ['Education']}],
#    'researchers': [{'first_name': 'Rebecca Ann',
#      'id': 'ur.01104515603.38',
#      'last_name': 'Piskorowski',
#      'orcid_id': ['0000-0003-0120-2360'],
#      'research_orgs': ['grid.266102.1',
#       'grid.89336.37',
#       'grid.21729.3f',
#       'grid.7429.8',
#       'grid.512035.0',
#       'grid.508487.6',
#       'grid.414435.3',
#       'grid.503253.2',
#       'grid.169077.e',
#       'grid.168010.e',
#       'grid.413734.6',
#       'grid.10988.38']},
#     {'first_name': 'Kaoutsar',
#      'id': 'ur.0760362501.07',
#      'last_name': 'Nasrallah',
#      'orcid_id': ['0000-0002-2627-7417'],
#      'research_orgs': ['grid.251993.5', 'grid.508487.6']},
#     {'first_name': 'Anastasia',
#      'id': 'ur.0706726200.29',
#      'last_name': 'Diamantopoulou',
#      'orcid_id': ['0000-0002-3350-0330'],
#      'research_orgs': ['grid.10419.3d',
#       'grid.5216.0',
#       'grid.239585.0',
#       'grid.5132.5',
#       'grid.21729.3f']},
#     {'first_name': 'Jun',
#      'id': 'ur.0740477677.49',
#      'last_name': 'Mukai',
#      'orcid_id': ['0000-0003-2065-4784'],
#      'research_orgs': ['grid.20515.33', 'grid.21729.3f', 'grid.260026.0']},
#     {'first_name': 'Sami I H',
#      'id': 'ur.01073325623.62',
#      'last_name': 'Hassan',
#      'orcid_id': ['0000-0002-8784-143X'],
#      'research_orgs': ['grid.5252.0', 'grid.452396.f', 'grid.21729.3f']},
#     {'first_name': 'Steven A',
#      'id': 'ur.01315344633.00',
#      'last_name': 'Siegelbaum',
#      'orcid_id': ['0000-0002-0242-7505'],
#      'research_orgs': ['grid.267313.2',
#       'grid.280268.6',
#       'grid.239585.0',
#       'grid.413575.1',
#       'grid.413734.6',
#       'grid.267308.8',
#       'grid.38142.3c',
#       'grid.21729.3f']},
#     {'first_name': 'Joseph A',
#      'id': 'ur.0655077242.99',
#      'last_name': 'Gogos',
#      'research_orgs': ['grid.461177.2',
#       'grid.214458.e',
#       'grid.21729.3f',
#       'grid.420085.b',
#       'grid.116068.8',
#       'grid.416868.5',
#       'grid.51462.34',
#       'grid.38142.3c',
#       'grid.34477.33',
#       'grid.21925.3d',
#       'grid.7872.a',
#       'grid.270240.3',
#       'grid.239585.0',
#       'grid.134907.8',
#       'grid.5386.8',
#       'grid.49697.35',
#       'grid.413734.6',
#       'grid.9668.1',
#       'grid.257167.0']},
#     {'first_name': 'Vivien',
#      'id': 'ur.01152631003.22',
#      'last_name': 'Chevaleyre',
#      'orcid_id': ['0000-0002-3679-4856'],
#      'research_orgs': ['grid.7429.8',
#       'grid.21729.3f',
#       'grid.512035.0',
#       'grid.508487.6',
#       'grid.251993.5',
#       'grid.433120.7',
#       'grid.414435.3',
#       'grid.503253.2',
#       'grid.4444.0',
#       'grid.10988.38']}],
#    'times_cited': 120,
#    'title': 'Age-Dependent Specific Changes in Area CA2 of the Hippocampus and Social Memory Deficit in a Mouse Model of the 22q11.2 Deletion Syndrome',
#    'type': 'article',
#    'year': 2016},
#   {'acknowledgements': 'This work was supported by NIH grants AI116320, AI027767 (SS), and AI103401-01 (MCK and MSS). All flow cytometry experiments were performed by the UAB CFAR Flow Cytometry Core/ Joint UAB Flow Cytometry Facility and were funded in part by NIH/NIAID P30 AI27767. We thank Catrena Johnson, Pamela Cunningham, and Zenoria Causey for recruiting the women in this study; Alice Howell and Kathy Carter for procuring remnant tissue samples; and all of the volunteers for participating in these studies. Data in this manuscript were collected by the Women&#x27;s Interagency HIV Study (WIHS). The contents of this publication are solely the responsibility of the authors and do not represent the official views of the National Institutes of Health (NIH). WIHS Principal Investigators: UAB-MS WIHS (Michael Saag, Mirjam-Colette Kempf, and Deborah Konkle-Parker); U01-AI-103401. The WIHS is funded primarily by the National Institute of Allergy and Infectious Diseases (NIAID), with additional co-funding from the Eunice Kennedy Shriver National Institute of Child Health and Human Development (NICHD), the National Cancer Institute (NCI), the National Institute on Drug Abuse (NIDA), and the National Institute on Mental Health (NIMH). Targeted supplemental funding for specific projects is also provided by the National Institute of Dental and Craniofacial Research (NIDCR), the National Institute on Alcohol Abuse and Alcoholism (NIAAA), the National Institute on Deafness and other Communication Disorders (NIDCD), and the NIH Office of Research on Women&#x27;s Health. WIHS data collection is also supported by UL1-TR000004 (UCSF CTSA) and UL1-TR000454 (Atlanta CTSA).',
#    'altmetric_id': 0,
#    'authors_count': 7,
#    'category_for': [{'id': '80050', 'name': '3207 Medical Microbiology'},
#     {'id': '80003', 'name': '32 Biomedical and Clinical Sciences'},
#     {'id': '80047', 'name': '3204 Immunology'}],
#    'concepts': ['HIV-positive women',
#     'female genital tract',
#     'expression of CD103',
#     'resident T cells',
#     'T cells',
#     'CD103 expression',
#     'genital tract',
#     'antigen-specific IFN-γ production',
#     'tissue-resident memory T cells',
#     'resident memory T cells',
#     'human female genital tract',
#     'memory T cells',
#     'IFN-γ production',
#     'HIV-1 infection',
#     'polychromatic flow cytometry',
#     'TRM cells',
#     'mucosal CD4',
#     'healthy women',
#     'T-bet',
#     'CD103',
#     'murine model',
#     'mucosal surfaces',
#     'CD4',
#     'CD8',
#     'flow cytometry',
#     'mucosa',
#     'women',
#     'cells/',
#     'enhanced response',
#     'infection',
#     'tract',
#     'cells',
#     'expression',
#     'CD69',
#     'cytometry',
#     'receptors',
#     'lt',
#     'humans',
#     'response',
#     'TRM',
#     'role',
#     'function',
#     'data',
#     'production',
#     'model',
#     'surface'],
#    'date': '2016-01-01',
#    'doi': '10.20411/pai.v1i2.166',
#    'field_citation_ratio': 3.31,
#    'id': 'pub.1083685161',
#    'journal': {'id': 'jour.1284304', 'title': 'Pathogens and Immunity'},
#    'journal_title_raw': 'Pathogens and Immunity',
#    'linkout': 'https://paijournal.com/index.php/paijournal/article/download/166/86',
#    'open_access': ['oa_all', 'gold'],
#    'publisher': 'Case Western Reserve University',
#    'research_org_countries': [{'id': 'US', 'name': 'United States'}],
#    'research_orgs': [{'acronym': 'UAB',
#      'city_name': 'Birmingham',
#      'country_name': 'United States',
#      'id': 'grid.265892.2',
#      'latitude': 33.500675,
#      'linkout': ['http://www.uab.edu/'],
#      'longitude': -86.805824,
#      'name': 'University of Alabama at Birmingham',
#      'state_name': 'Alabama',
#      'types': ['Education']}],
#    'researchers': [{'first_name': 'David C',
#      'id': 'ur.015536510323.10',
#      'last_name': 'Moylan',
#      'research_orgs': ['grid.265892.2']},
#     {'first_name': 'Paul Andres',
#      'id': 'ur.0625272302.13',
#      'last_name': 'Goepfert',
#      'orcid_id': ['0000-0001-8441-5737'],
#      'research_orgs': ['grid.34477.33',
#       'grid.16463.36',
#       'grid.32224.35',
#       'grid.94365.3d',
#       'grid.510993.7',
#       'grid.259828.c',
#       'grid.189967.8',
#       'grid.516065.1',
#       'grid.419681.3',
#       'grid.413575.1',
#       'grid.25879.31',
#       'grid.239573.9',
#       'grid.148313.c',
#       'grid.412359.8',
#       'grid.265892.2',
#       'grid.189509.c']},
#     {'first_name': 'Mirjam-Colette',
#      'id': 'ur.01223704767.16',
#      'last_name': 'Kempf',
#      'research_orgs': ['grid.8379.5',
#       'grid.265892.2',
#       'grid.12984.36',
#       'grid.79746.3b',
#       'grid.10698.36',
#       'grid.189967.8',
#       'grid.415794.a']},
#     {'first_name': 'Michael S',
#      'id': 'ur.012476020677.16',
#      'last_name': 'Saag',
#      'orcid_id': ['0000-0002-8866-1043'],
#      'research_orgs': ['grid.418015.9',
#       'grid.189967.8',
#       'grid.239844.0',
#       'grid.32224.35',
#       'grid.419178.2',
#       'grid.413019.e',
#       'grid.416732.5',
#       'grid.411439.a',
#       'grid.5337.2',
#       'grid.411015.0',
#       'grid.67033.31',
#       'grid.419681.3',
#       'grid.417993.1',
#       'grid.270240.3',
#       'grid.280808.a',
#       'grid.79746.3b',
#       'grid.10698.36',
#       'grid.240873.a',
#       'grid.240952.8',
#       'grid.21925.3d',
#       'grid.514151.5',
#       'grid.34477.33',
#       'grid.38142.3c',
#       'grid.411097.a',
#       'grid.94365.3d',
#       'grid.4367.6',
#       'grid.26790.3a',
#       'grid.265892.2',
#       'grid.59734.3c',
#       'grid.266102.1',
#       'grid.8991.9',
#       'grid.7429.8',
#       'grid.8217.c',
#       'grid.428045.f',
#       'grid.189504.1',
#       'grid.436080.9',
#       'grid.418019.5',
#       'grid.245849.6',
#       'grid.266100.3',
#       'grid.21107.35',
#       'grid.12984.36']},
#     {'first_name': 'Holly Elizabeth',
#      'id': 'ur.011425313517.06',
#      'last_name': 'Richter',
#      'orcid_id': ['0000-0001-7741-5771'],
#      'research_orgs': ['grid.164971.c',
#       'grid.26009.3d',
#       'grid.89336.37',
#       'grid.413334.2',
#       'grid.38142.3c',
#       'grid.416738.f',
#       'grid.266900.b',
#       'grid.280808.a',
#       'grid.24827.3b',
#       'grid.514151.5',
#       'grid.241054.6',
#       'grid.488770.4',
#       'grid.66875.3a',
#       'grid.147455.6',
#       'grid.170205.1',
#       'grid.411487.f',
#       'grid.411115.1',
#       'grid.280062.e',
#       'grid.176731.5',
#       'grid.413420.0',
#       'grid.59734.3c',
#       'grid.239638.5',
#       'grid.412016.0',
#       'grid.213910.8',
#       'grid.254444.7',
#       'grid.63054.34',
#       'grid.26790.3a',
#       'grid.411024.2',
#       'grid.34474.30',
#       'grid.214572.7',
#       'grid.418246.d',
#       'grid.411015.0',
#       'grid.239424.a',
#       'grid.240267.5',
#       'grid.17866.3e',
#       'grid.266832.b',
#       'grid.438526.e',
#       'grid.39382.33',
#       'grid.21107.35',
#       'grid.67033.31',
#       'grid.261331.4',
#       'grid.259828.c',
#       'grid.417118.a',
#       'grid.454407.6',
#       'grid.215352.2',
#       'grid.413019.e',
#       'grid.214458.e',
#       'grid.19006.3e',
#       'grid.267301.1',
#       'grid.152326.1',
#       'grid.239578.2',
#       'grid.16753.36',
#       'grid.17088.36',
#       'grid.410372.3',
#       'grid.416732.5',
#       'grid.265892.2',
#       'grid.168010.e',
#       'grid.411569.e',
#       'grid.254567.7',
#       'grid.478063.e',
#       'grid.21925.3d',
#       'grid.15276.37',
#       'grid.460217.6',
#       'grid.413052.1',
#       'grid.281208.1',
#       'grid.417538.c',
#       'grid.240416.5',
#       'grid.277313.3',
#       'grid.420089.7',
#       'grid.414895.5',
#       'grid.267313.2',
#       'grid.417468.8',
#       'grid.280460.8',
#       'grid.223827.e',
#       'grid.430754.1',
#       'grid.516103.0',
#       'grid.461921.9',
#       'grid.62562.35',
#       'grid.410711.2',
#       'grid.32224.35',
#       'grid.267309.9',
#       'grid.266100.3',
#       'grid.40263.33',
#       'grid.411935.b',
#       'grid.189509.c',
#       'grid.266102.1',
#       'grid.94365.3d',
#       'grid.412689.0',
#       'grid.17091.3e',
#       'grid.420234.3',
#       'grid.419635.c',
#       'grid.239585.0',
#       'grid.270240.3',
#       'grid.411451.4',
#       'grid.10698.36',
#       'grid.134563.6',
#       'grid.189967.8',
#       'grid.241223.4',
#       'grid.25879.31',
#       'grid.255272.5',
#       'grid.34477.33',
#       'grid.415235.4',
#       'grid.67105.35',
#       'grid.266539.d',
#       'grid.5288.7',
#       'grid.241167.7',
#       'grid.411931.f',
#       'grid.476934.b',
#       'grid.412154.7',
#       'grid.4367.6',
#       'grid.30389.31']},
#     {'first_name': 'Jiri F',
#      'id': 'ur.01213632267.99',
#      'last_name': 'Mestecky',
#      'orcid_id': ['0000-0001-8133-2119'],
#      'research_orgs': ['grid.185006.a',
#       'grid.254444.7',
#       'grid.21729.3f',
#       'grid.4514.4',
#       'grid.410566.0',
#       'grid.418800.5',
#       'grid.136593.b',
#       'grid.134907.8',
#       'grid.5342.0',
#       'grid.27860.3b',
#       'grid.10419.3d',
#       'grid.47100.32',
#       'grid.67105.35',
#       'grid.40263.33',
#       'grid.94365.3d',
#       'grid.413019.e',
#       'grid.1003.2',
#       'grid.176731.5',
#       'grid.254567.7',
#       'grid.454428.b',
#       'grid.25073.33',
#       'grid.267313.2',
#       'grid.4491.8',
#       'grid.223827.e',
#       'grid.416167.3',
#       'grid.417118.a',
#       'grid.265892.2',
#       'grid.38142.3c',
#       'grid.24827.3b',
#       'grid.418095.1',
#       'grid.42505.36',
#       'grid.8761.8',
#       'grid.420089.7',
#       'grid.154185.c',
#       'grid.419681.3',
#       'grid.412590.b',
#       'grid.418930.7',
#       'grid.7048.b',
#       'grid.422976.c',
#       'grid.10979.36',
#       'grid.419633.a',
#       'grid.241116.1',
#       'grid.260969.2',
#       'grid.4858.1',
#       'grid.410821.e',
#       'grid.273335.3',
#       'grid.258269.2',
#       'grid.267309.9',
#       'grid.5734.5',
#       'grid.267301.1',
#       'grid.5132.5',
#       'grid.413120.5',
#       'grid.411015.0',
#       'grid.241104.2']},
#     {'first_name': 'Steffanie',
#      'id': 'ur.01200300764.41',
#      'last_name': 'Sabbaj',
#      'orcid_id': ['0000-0003-4052-6819'],
#      'research_orgs': ['grid.413019.e',
#       'grid.148313.c',
#       'grid.259828.c',
#       'grid.239573.9',
#       'grid.265892.2',
#       'grid.262962.b',
#       'grid.261331.4']}],
#    'times_cited': 22,
#    'title': 'Diminished CD103 (aEb7) Expression on Resident T cells from the Female Genital Tract of HIV-positive women',
#    'type': 'article',
#    'year': 2016}]}

# %% [markdown]
# Checking the number of publications.

# %%
sum(len(l['publications']) for l in dimensions_data)
# Out:
# 400

# %%
print(f"The results are stored in a nested array, where each item contains a number of publications nested within. To see the number of publications in each item lookup `{list(dimensions_data[0])[0]}`, whereas to access the publications lookup `{list(dimensions_data[0])[1]}`.")
# Out:
# The results are stored in a nested array, where each item contains a number of publications nested within. To see the number of publications in each item lookup `_stats`, whereas to access the publications lookup `publications`.

# %% [markdown]
# There are two main ways to access the articles within our collection. First, to retrieve them by their DOI using the `doi` key and the doi python package. This option mainly returns HTML pages. Second, to use the `linkout` key which sometimes returns HTML pages but often returns URL to the article in PDF format. I assume that if a PDF is returned it most likely includes the full-text of the article, whereas I cannot say this about the HTML pages. Moreover, downloading PDFs are faster than accessing HTML pages.

# %% [markdown]
# Also, some articles within our collection are open access whereas others are closed. This too can influence whether we can access the full-text of the manuscript to scrape. Thus, we first look at the number of open-access and closed articles that include the URL to the PDF in order to make a more informed search strategy.

# %%
# Creating a df to store results
includes_pdf = pd.DataFrame(columns=["open_access", "pdf"])
# Extracting whether the article includes a pdf or not
for batch in dimensions_data:
    for publication in batch['publications']:
        # Search PDF format at the end of the linkout
        match = re.match(r".*pdf$", publication['linkout'])
        includes_pdf = pd.concat([includes_pdf,
                                  pd.DataFrame([
                                      {"open_access": publication['open_access'][0], "pdf": bool(match)}
                                  ])
                                 ])
# Summarizing the results
includes_pdf.groupby(['open_access', 'pdf']).value_counts()
# Out:
# open_access  pdf
# oa_all       False    131
#              True     269
# Name: count, dtype: int64

# %% [markdown]
# The PDF is present in more than half of the cases. It would be better to access just the HTML pages so we can use one extraction method. Some webpages are protected by cloudflare so we would need to use selenium to access the content. Opening the HTML pages are more time consuming then downloading the PDFs. Since we have a lot of files we download the PDFs wherever possible to save time. The downside is that PDF files take up much more space when downloaded. While it is better to save the files locally and then extract the information in a separate step (as in case of errors we do not have to download the file again), to save space we might download the file, extract the information and then delete the file. Also, it is a possible solution to keep batches of files at a time and proceed once the batch is cleaned up.

# %% [markdown]
# Note:
# * It is also possible that downloading 1.6 million publications would take forever. Thus, we can download a few thousand from each year for each journal title.
# * For open access papers we could search for the download link of the PDF of the full-text but that would take more time and lead to possible errors.

# %% [markdown]
# ## Scraping CRediT statements

# %% [markdown]
# ### Listing publications for scraping

# %% [markdown]
# Creating an array of publications with id, doi, and linkout for download.

# %%
# Creating a container for storing the linkouts
publication_list = []
# Extracting linkouts and flagging PDFs
## We also flag whether a paper is open access or not
for batch in dimensions_data:
    for publication in batch['publications']:
        publication_list.append({'id': publication['id'], 'doi': publication['doi'], 'linkout': publication['linkout'], 'pdf': bool(re.match(r".*pdf$", publication['linkout']))})
        
# Returning the first few results
publication_list[1:100]
# Out:
# [{'id': 'pub.1035271577',
#   'doi': '10.1016/j.chembiol.2015.11.013',
#   'linkout': 'http://www.cell.com/article/S2451945616000258/pdf',
#   'pdf': True},
#  {'id': 'pub.1017265217',
#   'doi': '10.1016/j.molcel.2016.01.004',
#   'linkout': 'http://www.cell.com/article/S1097276516000058/pdf',
#   'pdf': True},
#  {'id': 'pub.1012497217',
#   'doi': '10.1016/j.celrep.2016.01.007',
#   'linkout': 'http://www.cell.com/article/S2211124716000279/pdf',
#   'pdf': True},
#  {'id': 'pub.1002596264',
#   'doi': '10.1016/j.cub.2015.12.045',
#   'linkout': 'http://www.cell.com/article/S0960982215015766/pdf',
#   'pdf': True},
#  {'id': 'pub.1047271733',
#   'doi': '10.1016/j.str.2015.12.008',
#   'linkout': 'http://www.cell.com/article/S0969212615005341/pdf',
#   'pdf': True},
#  {'id': 'pub.1045666532',
#   'doi': '10.1016/j.celrep.2015.12.089',
#   'linkout': 'https://doi.org/10.1016/j.celrep.2015.12.089',
#   'pdf': False},
#  {'id': 'pub.1039891981',
#   'doi': '10.1016/j.neuron.2015.12.020',
#   'linkout': 'http://www.cell.com/article/S0896627315011228/pdf',
#   'pdf': True},
#  {'id': 'pub.1034674785',
#   'doi': '10.1016/j.celrep.2015.12.083',
#   'linkout': 'http://www.cell.com/article/S2211124715015399/pdf',
#   'pdf': True},
#  {'id': 'pub.1025201128',
#   'doi': '10.1016/j.neuron.2015.12.019',
#   'linkout': 'http://www.cell.com/article/S0896627315011216/pdf',
#   'pdf': True},
#  {'id': 'pub.1021386742',
#   'doi': '10.1016/j.celrep.2015.12.084',
#   'linkout': 'http://www.cell.com/article/S2211124715015405/pdf',
#   'pdf': True},
#  {'id': 'pub.1010727419',
#   'doi': '10.1016/j.molp.2016.01.006',
#   'linkout': 'http://www.cell.com/article/S1674205216000083/pdf',
#   'pdf': True},
#  {'id': 'pub.1006000358',
#   'doi': '10.1016/j.cell.2015.12.050',
#   'linkout': 'https://doi.org/10.1016/j.cell.2015.12.050',
#   'pdf': False},
#  {'id': 'pub.1004343432',
#   'doi': '10.1016/j.celrep.2015.12.099',
#   'linkout': 'http://www.cell.com/article/S2211124715015557/pdf',
#   'pdf': True},
#  {'id': 'pub.1003918497',
#   'doi': '10.1016/j.celrep.2015.12.100',
#   'linkout': 'https://doi.org/10.1016/j.celrep.2015.12.100',
#   'pdf': False},
#  {'id': 'pub.1015757601',
#   'doi': '10.1016/j.molp.2016.01.007',
#   'linkout': 'http://www.cell.com/article/S1674205216000095/pdf',
#   'pdf': True},
#  {'id': 'pub.1048739997',
#   'doi': '10.1016/j.celrep.2015.12.068',
#   'linkout': 'http://www.cell.com/article/S2211124715015223/pdf',
#   'pdf': True},
#  {'id': 'pub.1044968140',
#   'doi': '10.1016/j.cell.2015.12.038',
#   'linkout': 'http://www.cell.com/article/S009286741501702X/pdf',
#   'pdf': True},
#  {'id': 'pub.1020776884',
#   'doi': '10.1016/j.celrep.2015.12.066',
#   'linkout': 'http://www.cell.com/article/S221112471501520X/pdf',
#   'pdf': True},
#  {'id': 'pub.1019323049',
#   'doi': '10.1016/j.celrep.2015.12.073',
#   'linkout': 'http://www.cell.com/article/S2211124715015296/pdf',
#   'pdf': True},
#  {'id': 'pub.1021909445',
#   'doi': '10.1016/j.stemcr.2015.12.006',
#   'linkout': 'http://www.cell.com/article/S2213671115003719/pdf',
#   'pdf': True},
#  {'id': 'pub.1044078806',
#   'doi': '10.1038/srep19209',
#   'linkout': 'https://www.nature.com/articles/srep19209.pdf',
#   'pdf': True},
#  {'id': 'pub.1042954242',
#   'doi': '10.1016/j.str.2015.11.015',
#   'linkout': 'http://www.cell.com/article/S0969212615005043/pdf',
#   'pdf': True},
#  {'id': 'pub.1037869012',
#   'doi': '10.1016/j.neuron.2015.12.012',
#   'linkout': 'http://www.cell.com/article/S0896627315010855/pdf',
#   'pdf': True},
#  {'id': 'pub.1037653150',
#   'doi': '10.1016/j.cub.2015.11.060',
#   'linkout': 'http://www.cell.com/article/S0960982215015080/pdf',
#   'pdf': True},
#  {'id': 'pub.1043481739',
#   'doi': '10.7554/elife.10921',
#   'linkout': 'https://doi.org/10.7554/elife.10921',
#   'pdf': False},
#  {'id': 'pub.1012405704',
#   'doi': '10.1038/srep18536',
#   'linkout': 'https://www.nature.com/articles/srep18536.pdf',
#   'pdf': True},
#  {'id': 'pub.1053662687',
#   'doi': '10.1242/jeb.148957',
#   'linkout': 'https://doi.org/10.1242/jeb.148957',
#   'pdf': False},
#  {'id': 'pub.1053136983',
#   'doi': '10.1242/jcs.192450',
#   'linkout': 'https://doi.org/10.1242/jcs.192450',
#   'pdf': False},
#  {'id': 'pub.1052269666',
#   'doi': '10.1242/bio.018226',
#   'linkout': 'https://doi.org/10.1242/bio.018226',
#   'pdf': False},
#  {'id': 'pub.1052252199',
#   'doi': '10.1242/jcs.135194',
#   'linkout': 'https://scholarlypublications.universiteitleiden.nl/access/item%3A2892446/view',
#   'pdf': False},
#  {'id': 'pub.1049904160',
#   'doi': '10.1242/dev.138743',
#   'linkout': 'https://dev.biologists.org/content/develop/143/17/3085.full.pdf',
#   'pdf': True},
#  {'id': 'pub.1045879530',
#   'doi': '10.1242/dev.139642',
#   'linkout': 'https://doi.org/10.1242/dev.139642',
#   'pdf': False},
#  {'id': 'pub.1045422486',
#   'doi': '10.1242/dev.130955',
#   'linkout': 'http://dev.biologists.org/content/143/19/3560.full.pdf',
#   'pdf': True},
#  {'id': 'pub.1042730321',
#   'doi': '10.1242/jcs.195321',
#   'linkout': 'https://doi.org/10.1242/jcs.195321',
#   'pdf': False},
#  {'id': 'pub.1039074739',
#   'doi': '10.1242/jeb.143750',
#   'linkout': 'https://pure.au.dk/portal/files/119261347/2726.full.pdf',
#   'pdf': True},
#  {'id': 'pub.1038492240',
#   'doi': '10.1242/dmm.022665',
#   'linkout': 'https://doi.org/10.1242/dmm.022665',
#   'pdf': False},
#  {'id': 'pub.1037561457',
#   'doi': '10.1242/dev.132738',
#   'linkout': 'https://doi.org/10.1242/dev.132738',
#   'pdf': False},
#  {'id': 'pub.1035291865',
#   'doi': '10.1242/dev.129155',
#   'linkout': 'https://doi.org/10.1242/dev.129155',
#   'pdf': False},
#  {'id': 'pub.1035106588',
#   'doi': '10.1242/dev.143354',
#   'linkout': 'https://doi.org/10.1242/dev.143354',
#   'pdf': False},
#  {'id': 'pub.1033970908',
#   'doi': '10.1242/jcs.193086',
#   'linkout': 'https://doi.org/10.1242/jcs.193086',
#   'pdf': False},
#  {'id': 'pub.1033635216',
#   'doi': '10.1242/dmm.026989',
#   'linkout': 'https://dmm.biologists.org/content/dmm/10/1/63.full.pdf',
#   'pdf': True},
#  {'id': 'pub.1033267567',
#   'doi': '10.1242/jcs.188185',
#   'linkout': 'https://jcs.biologists.org/content/joces/130/1/243.full.pdf',
#   'pdf': True},
#  {'id': 'pub.1033192651',
#   'doi': '10.1242/jcs.195164',
#   'linkout': 'https://doi.org/10.1242/jcs.195164',
#   'pdf': False},
#  {'id': 'pub.1029987065',
#   'doi': '10.1242/dmm.027185',
#   'linkout': 'https://doi.org/10.1242/dmm.027185',
#   'pdf': False},
#  {'id': 'pub.1028645813',
#   'doi': '10.1242/dev.139238',
#   'linkout': 'https://doi.org/10.1242/dev.139238',
#   'pdf': False},
#  {'id': 'pub.1027979521',
#   'doi': '10.1242/dev.138271',
#   'linkout': 'https://dev.biologists.org/content/develop/144/2/201.full.pdf',
#   'pdf': True},
#  {'id': 'pub.1027162211',
#   'doi': '10.1242/jcs.194886',
#   'linkout': 'https://doi.org/10.1242/jcs.194886',
#   'pdf': False},
#  {'id': 'pub.1026241675',
#   'doi': '10.1242/jeb.127159',
#   'linkout': 'https://jeb.biologists.org/content/jexbio/219/20/3208.full.pdf',
#   'pdf': True},
#  {'id': 'pub.1025149546',
#   'doi': '10.1242/dev.137489',
#   'linkout': 'https://doi.org/10.1242/dev.137489',
#   'pdf': False},
#  {'id': 'pub.1024722737',
#   'doi': '10.1242/jcs.193367',
#   'linkout': 'https://jcs.biologists.org/content/joces/129/17/3251.full.pdf',
#   'pdf': True},
#  {'id': 'pub.1023645600',
#   'doi': '10.1242/jcs.171124',
#   'linkout': 'https://europepmc.org/articles/pmc5047704',
#   'pdf': False},
#  {'id': 'pub.1022893599',
#   'doi': '10.1242/dev.143263',
#   'linkout': 'https://doi.org/10.1242/dev.143263',
#   'pdf': False},
#  {'id': 'pub.1022835092',
#   'doi': '10.1242/jcs.189423',
#   'linkout': 'https://jcs.biologists.org/content/joces/129/17/3231.full.pdf',
#   'pdf': True},
#  {'id': 'pub.1022611087',
#   'doi': '10.1242/dev.137760',
#   'linkout': 'https://dev.biologists.org/content/develop/143/21/3994.full.pdf',
#   'pdf': True},
#  {'id': 'pub.1022376050',
#   'doi': '10.1242/dev.137067',
#   'linkout': 'https://repository.kulib.kyoto-u.ac.jp/dspace/bitstream/2433/252845/1/dev.137067.pdf',
#   'pdf': True},
#  {'id': 'pub.1022360940',
#   'doi': '10.1242/dmm.027037',
#   'linkout': 'http://dmm.biologists.org/content/dmm/9/12/1445.full.pdf',
#   'pdf': True},
#  {'id': 'pub.1022099332',
#   'doi': '10.1242/dmm.026518',
#   'linkout': 'https://doi.org/10.1242/dmm.026518',
#   'pdf': False},
#  {'id': 'pub.1021414252',
#   'doi': '10.1242/jeb.141424',
#   'linkout': 'https://air.unimi.it/bitstream/2434/450962/2/Cecere%202016.pdf',
#   'pdf': True},
#  {'id': 'pub.1020589296',
#   'doi': '10.1242/jeb.147884',
#   'linkout': 'https://doi.org/10.1242/jeb.147884',
#   'pdf': False},
#  {'id': 'pub.1020518509',
#   'doi': '10.1242/dev.129338',
#   'linkout': 'https://ri.conicet.gov.ar/bitstream/11336/76546/2/CONICET_Digital_Nro.4d1b93bc-2f6a-4e8c-a8ae-ff403787433d_A.pdf',
#   'pdf': True},
#  {'id': 'pub.1017197759',
#   'doi': '10.1242/dev.143545',
#   'linkout': 'https://doi.org/10.1242/dev.143545',
#   'pdf': False},
#  {'id': 'pub.1015942168',
#   'doi': '10.1242/dev.135152',
#   'linkout': 'https://doi.org/10.1242/dev.135152',
#   'pdf': False},
#  {'id': 'pub.1011899591',
#   'doi': '10.1242/dev.139253',
#   'linkout': 'https://doi.org/10.1242/dev.139253',
#   'pdf': False},
#  {'id': 'pub.1010162998',
#   'doi': '10.1242/jcs.196741',
#   'linkout': 'https://doi.org/10.1242/jcs.196741',
#   'pdf': False},
#  {'id': 'pub.1009467060',
#   'doi': '10.1242/jeb.146605',
#   'linkout': 'https://doi.org/10.1242/jeb.146605',
#   'pdf': False},
#  {'id': 'pub.1007920920',
#   'doi': '10.1242/jeb.151043',
#   'linkout': 'https://doi.org/10.1242/jeb.151043',
#   'pdf': False},
#  {'id': 'pub.1007627950',
#   'doi': '10.1242/dev.135947',
#   'linkout': 'https://doi.org/10.1242/dev.135947',
#   'pdf': False},
#  {'id': 'pub.1004820871',
#   'doi': '10.1242/jcs.188862',
#   'linkout': 'https://jcs.biologists.org/content/joces/129/20/3744.full.pdf',
#   'pdf': True},
#  {'id': 'pub.1004617914',
#   'doi': '10.1242/dev.140889',
#   'linkout': 'https://europepmc.org/articles/pmc5117147',
#   'pdf': False},
#  {'id': 'pub.1003212449',
#   'doi': '10.1242/jeb.140772',
#   'linkout': 'https://doi.org/10.1242/jeb.140772',
#   'pdf': False},
#  {'id': 'pub.1002208544',
#   'doi': '10.1242/jcs.195503',
#   'linkout': 'https://jcs.biologists.org/content/joces/130/2/480.full.pdf',
#   'pdf': True},
#  {'id': 'pub.1001626415',
#   'doi': '10.1242/jeb.151084',
#   'linkout': 'https://doi.org/10.1242/jeb.151084',
#   'pdf': False},
#  {'id': 'pub.1001110364',
#   'doi': '10.1242/dev.139550',
#   'linkout': 'https://doi.org/10.1242/dev.139550',
#   'pdf': False},
#  {'id': 'pub.1000483469',
#   'doi': '10.1242/dev.136879',
#   'linkout': 'https://doi.org/10.1242/dev.136879',
#   'pdf': False},
#  {'id': 'pub.1050339301',
#   'doi': '10.1016/j.neuron.2015.12.017',
#   'linkout': 'http://www.cell.com/article/S0896627315011198/pdf',
#   'pdf': True},
#  {'id': 'pub.1048417518',
#   'doi': '10.1016/j.cell.2015.12.025',
#   'linkout': 'http://www.cell.com/article/S009286741501689X/pdf',
#   'pdf': True},
#  {'id': 'pub.1042653442',
#   'doi': '10.1016/j.devcel.2015.12.016',
#   'linkout': 'http://www.cell.com/article/S1534580715008011/pdf',
#   'pdf': True},
#  {'id': 'pub.1030700254',
#   'doi': '10.1016/j.devcel.2015.12.009',
#   'linkout': 'https://doi.org/10.1016/j.devcel.2015.12.009',
#   'pdf': False},
#  {'id': 'pub.1029832579',
#   'doi': '10.1016/j.neuron.2015.12.014',
#   'linkout': 'http://www.cell.com/article/S0896627315010879/pdf',
#   'pdf': True},
#  {'id': 'pub.1029645663',
#   'doi': '10.1016/j.neuron.2015.12.018',
#   'linkout': 'http://www.cell.com/article/S0896627315011204/pdf',
#   'pdf': True},
#  {'id': 'pub.1012963447',
#   'doi': '10.1016/j.neuron.2015.12.008',
#   'linkout': 'http://www.cell.com/article/S0896627315010806/pdf',
#   'pdf': True},
#  {'id': 'pub.1012801617',
#   'doi': '10.1016/j.cell.2015.12.028',
#   'linkout': 'http://www.cell.com/article/S009286741501692X/pdf',
#   'pdf': True},
#  {'id': 'pub.1040580942',
#   'doi': '10.1016/j.cub.2015.11.049',
#   'linkout': 'http://www.cell.com/article/S0960982215014888/pdf',
#   'pdf': True},
#  {'id': 'pub.1038667419',
#   'doi': '10.1016/j.celrep.2015.12.040',
#   'linkout': 'http://www.cell.com/article/S2211124715014643/pdf',
#   'pdf': True},
#  {'id': 'pub.1038565089',
#   'doi': '10.1016/j.celrep.2015.12.022',
#   'linkout': 'http://www.cell.com/article/S2211124715014357/pdf',
#   'pdf': True},
#  {'id': 'pub.1031803934',
#   'doi': '10.1016/j.molcel.2015.12.008',
#   'linkout': 'http://www.cell.com/article/S1097276515009429/pdf',
#   'pdf': True},
#  {'id': 'pub.1026283426',
#   'doi': '10.1016/j.molp.2015.12.019',
#   'linkout': 'http://www.cell.com/article/S1674205215004967/pdf',
#   'pdf': True},
#  {'id': 'pub.1022731396',
#   'doi': '10.1016/j.str.2015.11.012',
#   'linkout': 'http://www.cell.com/article/S0969212615005018/pdf',
#   'pdf': True},
#  {'id': 'pub.1011354704',
#   'doi': '10.1016/j.celrep.2015.12.038',
#   'linkout': 'http://www.cell.com/article/S221112471501462X/pdf',
#   'pdf': True},
#  {'id': 'pub.1003556337',
#   'doi': '10.1016/j.cub.2015.11.050',
#   'linkout': 'http://www.cell.com/article/S096098221501489X/pdf',
#   'pdf': True},
#  {'id': 'pub.1003355431',
#   'doi': '10.1002/pro.2857',
#   'linkout': 'https://europepmc.org/articles/pmc4815421?pdf=render',
#   'pdf': False},
#  {'id': 'pub.1050114442',
#   'doi': '10.1016/j.ebiom.2015.12.020',
#   'linkout': 'http://www.ebiomedicine.com/article/S2352396415302486/pdf',
#   'pdf': True},
#  {'id': 'pub.1005848633',
#   'doi': '10.1016/j.cub.2015.11.033',
#   'linkout': 'http://www.cell.com/article/S096098221501427X/pdf',
#   'pdf': True},
#  {'id': 'pub.1046357282',
#   'doi': '10.1016/j.cels.2015.12.002',
#   'linkout': 'http://www.cell.com/article/S2405471215002161/pdf',
#   'pdf': True},
#  {'id': 'pub.1022548916',
#   'doi': '10.3389/fpls.2015.01158',
#   'linkout': 'https://www.frontiersin.org/articles/10.3389/fpls.2015.01158/pdf',
#   'pdf': True},
#  {'id': 'pub.1019691087',
#   'doi': '10.1016/j.molp.2015.12.011',
#   'linkout': 'http://www.cell.com/article/S1674205215004645/pdf',
#   'pdf': True},
#  {'id': 'pub.1040736256',
#   'doi': '10.1016/j.cub.2015.11.035',
#   'linkout': 'http://www.cell.com/article/S0960982215014293/pdf',
#   'pdf': True},
#  {'id': 'pub.1019836033',
#   'doi': '10.1016/j.celrep.2015.11.036',
#   'linkout': 'https://doi.org/10.1016/j.celrep.2015.11.036',
#   'pdf': False},
#  {'id': 'pub.1006776220',
#   'doi': '10.1016/j.cell.2015.12.015',
#   'linkout': 'http://www.cell.com/article/S0092867415016396/pdf',
#   'pdf': True}]

# %% [markdown]
# Getting the HTML or PDF file corresponding to each publication iteratively. We extract the PDFs whenever possible, otherwise we resort to the HTMLs.

# %% [markdown]
# ### Setting up webdriver

# %% [markdown]
# We tried using Firefox as our driver, however the driver got stuck after PDF download on new versions of Firefox. Thus, we resorted to using Chrome instead.

# %%
# Using Chrome webdriver

# Setting download directory
output_dir = os.path.abspath("data/publications/")

# Set Chrome browser preferences
options = ChromeOptions()
options.add_experimental_option('prefs',  {
    "download.default_directory": output_dir,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "plugins.always_open_pdf_externally": True,
    "safebrowsing.enabled": True
      }
  )

# Set driver options
#options.add_argument('--headless')
# In headless mode PDF files are not downloaded and there is no error message
# Some suggests firefox but that is not working for another reasons
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

# Adding chromedriver path during initiation
service = Service(r"/home/marton/Documents/chromedriver_linux64/chromedriver")
# Create a new Firefox browser instance
driver = webdriver.Chrome(service=service, options=options)

# %% [markdown]
# ### Exception handling

# %% [markdown]
# We will store error messages separately to deal with them later. Since we plan to scrape a lot of papers adding any error handling would immensely increase the amount of time it takes to scrape the publications. On the other hand we would like to run the code overnight. Therefore, we only apply a general try-catch. We also, note pages that we could download.

# %% [markdown]
# ### Downloading publications

# %%
def download_file(input, dir, driver):
    """
    Downloading PDF and HTML documents using Selenium
    
    Filenames are going to be the id for HTML pages, but will be random for PDFs. Renaming files would require wait time.
    
    :param input: Array where data corresponding to each file is stored in an object with the following keys:
        id: unique identifier of the publication
        linkout: link to the file to download
        pdf: true if the file is a pdf
    :param dir: Path to the dir where files should be downloaded
    :param driver: Webdriver to use for downloading
    
    :return: The function downloads the files as a side-effect and returns an array
        containing an object for each file with the following keys:
        id: the name of the file
        message: either an error message or 'downloaded'
    """
    # Create a container for storing the results
    res = []
    for publication in input:
        try:
            # If PDF is available downloading the file
            if publication['pdf']:
                # Print downloaded file info
                print(f"Downloading PDF file: {publication['linkout']}")
                # Download the PDF using Selenium
                # We have to use Selenium in order to avoid 403 by Cloudflare
                download_time = datetime.now()
                driver.get(publication['linkout'])
            # Every other case we download the HTML
            else:
                # Print downloaded file info
                print(f"Downloading HTML file: {publication['linkout']}")
                # Access the HTML
                ## It is possible that some pages use redirect links
                ## Waiting for pages to redirect would slow down process
                ## We will only resort to this if the number of downloaded files are limited
                driver.get(publication['linkout'])
                # Get the page source
                page_source = driver.page_source
                # Save the page source to a file
                ## Since some DOIs have backslashes we use Dimensions AI ID as a filename
                output_file = f"{publication['id']}.html"
                with open(os.path.join(output_dir, output_file), 'w', encoding='utf-8') as file:
                    file.write(page_source)
            res.append({'id': publication['id'], 'message': "downloaded"})
        except Exception as e:
            print(f"Error occured: {publication['linkout']}")
            print(str(e))
            res.append({'id': publication['id'], 'message': str(e)})
            continue
            
    # Returning the download state
    return res

# %%
# Downloading
download_list = []
for publication in input:
    download_list = download_file(input=publication_list[0:10], dir=output_dir, driver=driver)
# Out:
# Downloading PDF file: http://www.cell.com/article/S0960982215015596/pdf
# Downloading PDF file: http://www.cell.com/article/S2451945616000258/pdf
# Downloading PDF file: http://www.cell.com/article/S1097276516000058/pdf
# Downloading PDF file: http://www.cell.com/article/S2211124716000279/pdf
# Downloading PDF file: http://www.cell.com/article/S0960982215015766/pdf
# Downloading PDF file: http://www.cell.com/article/S0969212615005341/pdf
# Downloading HTML file: https://doi.org/10.1016/j.celrep.2015.12.089
# Downloading PDF file: http://www.cell.com/article/S0896627315011228/pdf
# Downloading PDF file: http://www.cell.com/article/S2211124715015399/pdf
# Downloading PDF file: http://www.cell.com/article/S0896627315011216/pdf

# %%
# Close the browser
## The driver has to ba closed later manually as it is possible that the last download is still on the way while the driver is closed
driver.quit()

# Save exceptions as a json
with open(os.path.abspath("data/downloaded-paper_list_data.json"), 'w') as f:
    json.dump(download_list, f)

# %% [markdown]
# It is possible that in case of the HTML files some downloaded sites do not contain the _Authors contribution_ section due to two main reasons: the HTML do not contain the full-text of the manuscript or the downloaded site is not the site of the paper (but only a redirect). Because of this, the following two counts are only approximations. These cases will be dropped during the extraction process.

# %% [markdown]
# The number of cases where we could access the publication:

# %%
#with open(os.path.abspath("data/downloaded-paper_list_data.json")) as json_data:
    #download_list = json.load(json_data)

# %%
sum(l['message'] == "downloaded" for l in download_list)
# Out:
# 6

# %%
download_list
# Out:
# [{'id': 'pub.1039110450', 'message': 'downloaded'},
#  {'id': 'pub.1035271577', 'message': 'downloaded'},
#  {'id': 'pub.1017265217', 'message': 'downloaded'},
#  {'id': 'pub.1012497217', 'message': 'downloaded'},
#  {'id': 'pub.1002596264', 'message': 'downloaded'},
#  {'id': 'pub.1047271733', 'message': 'downloaded'},
#  {'id': 'pub.1045666532', 'message': 'downloaded'},
#  {'id': 'pub.1039891981', 'message': 'downloaded'},
#  {'id': 'pub.1034674785', 'message': 'downloaded'},
#  {'id': 'pub.1025201128', 'message': 'downloaded'}]

# %% [markdown]
# The number of cases where we could not access the publication:

# %%
sum(l['message'] != "downloaded" for l in download_list)
# Out:
# 4

# %% [markdown]
# ### Extracting CRediT roles

# %% [markdown]
# Listing the downloaded articles.

# %%
publications_downloaded = os.listdir(output_dir)

# Show a few names
print(publications_downloaded[0:5])
# Out:
# ['pub.1045666532.html', 'PIIS0969212615005341.pdf', 'PIIS2451945616000258.pdf', 'PIIS2211124716000279.pdf', 'PIIS0960982215015596.pdf']

# %% [markdown]
# Trying to find a regular expression that catches _"Writing – original draft"_ regardless of how it is written.

# %%
pattern = r"(?i)\bwriting\b.{0,30}\boriginal\b.{0,30}\bdraft\b|\bwriting\b.{0,30}\bdraft\b.{0,30}\boriginal\b|\boriginal\b.{0,30}\bwriting\b.{0,30}\bdraft\b|\boriginal\b.{0,30}\bdraft\b.{0,30}\bwriting\b|\bdraft\b.{0,30}\bwriting\b.{0,30}\boriginal\b|\bdraft\b.{0,30}\boriginal\b.{0,30}\bwriting\b"
variations = ["Writing – original draft", "Writing – Original Draft", "Writing original draft", "Writing (Original draft)", "original draft writing", "Writing – review & editing", "Writing", "Original draft"]
for search_term in variations:
    match = re.match(pattern, search_term)
    if match:
        print("Search term:", search_term, "***", "Match found:", match.group())
    else:
        print("Search term:", search_term, "***", "Match not found")
# Out:
# Search term: Writing – original draft *** Match found: Writing – original draft
# Search term: Writing – Original Draft *** Match found: Writing – Original Draft
# Search term: Writing original draft *** Match found: Writing original draft
# Search term: Writing (Original draft) *** Match found: Writing (Original draft
# Search term: original draft writing *** Match found: original draft writing
# Search term: Writing – review & editing *** Match not found
# Search term: Writing *** Match not found
# Search term: Original draft *** Match not found

# %% [markdown]
# Extract the CRediT roles separately for the HTML and PDF files.

# %%
# Container for storing the results of the extraction
publication_results = []

# %%
def local_extraction(input, dir, search_term):
    """
    Extracting paragraphs from PDF and HTML documents stored in a local directory based on a search term.
    
    :param input: Array of file names
    :param dir: Path to the dir containing the files
    :param search_term: Regex pattern to search for
    
    :return: The function returns every paragprah including the search term from the document.
        The function returns an array containing an object for each file with the following keys:
        id: the name of the file
        index: unique identifier for each match within the file
        text: the text of the extracted paragraph
    """
    # Container for storing the results
    output = []
    # Extracting text from inputs
    for publication in input:
        # Check the format of the file
        extension = os.path.splitext(publication)[1]
        filename = os.path.splitext(publication)[0]
        # Create full path
        file_path = os.path.join(dir, publication)
        if extension == ".pdf":
            # Getting pdf metadata
            with open(file_path, 'rb') as f:
                reader = PdfReader(f)
                number_of_pages = len(reader.pages)
                meta = reader.metadata
                # Extracting text to pdfminer object
                ## Extracting pages separately
                for page_layout in extract_pages(f, laparams=LAParams()):
                    # Iterating through elements on the page
                    # It is possible that multiple elements contain the search term
                    # Returning every match
                    match_index = 0
                    for element in page_layout:
                        # Only working with text elements
                        if isinstance(element, LTTextContainer):
                            # Look for container containing the search term
                            match = re.search(search_term, element.get_text(), re.IGNORECASE)
                            if match:
                                output.append({'id': filename, 'index': match_index, 'text': element})
                                match_index += 1
        elif extension == ".html":
            # Parsing html
            with open(file_path, 'rb') as f:
                source = f.read()
                soup = BeautifulSoup(source, "html.parser")
            # Finding the container including the search term
            # Returning every match
            for index, element in enumerate(soup(text=re.compile(search_term))):
                output.append({'id': filename, 'index': index, 'text': element.parent.text})
    # Returning the results
    return output

# %%
publication_results = local_extraction(input=publications_downloaded, dir=output_dir, search_term=pattern)
publication_results[0:5]

# %% [markdown]
# Since we do not catch cases during extraction where we could not find the _Authors contributions_ text, we count the number of extracted CRediT statements now.

# %% [markdown]
# The number of matches (each publication could contain multiple matches):

# %% [markdown]
# The number of unique publiction with a match:

# %% [markdown]
# The number of cases where we could access the publication but could not extract the CRediT statement:

# %% [markdown]
# ## Exploring the results

# %% [markdown]
# Finding elements in the html files including our search term: "Writing – original draft". It is possible that the term is present multiple times (e.g. if the paper discusses the CRediT taxonomy instead of using it to report the authors' contributions). It is also possible that the search term is not present in the html file even though Dimension AI found it in their records corresponding to the given research article. This is possible as Dimensions AI does not report in which metadata the search term was found. Also, not all of the papers in our sample are open access. Thus, it is possible that the returned html does not include the section of the article containing our search term. We will flag these cases for further exploration.

# %% [markdown]
# Notes for myself: Do one with sci-hub instead it is cleaner. Create a version of the code where the pdf is mined after extraction, text is saved pdf is deleted. Use functions to make the code more flexible.
